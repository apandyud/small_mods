# %%
# code gen + values list

#### import tatqa_utils
import pandas as pd
import table_convert
import pyreadstat
#from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

import utils
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
import numpy as np
from progress.bar import Bar
# %load_ext autoreload
# %autoreload 2

# %%
from langchain_community.chat_models import ChatOllama
from langchain.schema import HumanMessage
llm = ChatOllama(model="llama3.2:1b")  # vagy bármely más elérhető Ollama modell

# %%
from langchain.globals import set_llm_cache
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
from langchain_community.cache import SQLiteCache

#llm = ChatOpenAI(temperature=0)
#llm = OpenAI(temperature=0) 
set_llm_cache(SQLiteCache(database_path=".langchain.ollama11.db"))

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
def get_question(qid):
    for i, item in devdf.iterrows():
        for q in item['questions']:        
            if q['uid'] == qid:
                #table = item['table']['table']
                return (item['table'], q)
    return (None, None)

# %%
import re

def extract_code_blocks(text):
    return "\n\n".join(re.findall(r'```(?:\w*\n)?(.*?)```', text, re.DOTALL))

def gen_code3(llm, messages, question, value_list): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"value_list": value_list, "question":question})
    print(response)
    code =  extract_code_blocks(response)
    
    return (prompt.format(value_list = value_list, question = question), code)

def exec_code(code, value_list):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({value_list})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

def gen_code_table(llm, messages, question, table): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"table": table, "question":question})
    code =  response.replace('```python','').replace('```','')
    
    return (prompt.format(table = table, question = question), code)

def exec_code_table(code, table):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({table})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

# %%
def get_answer(llm, messages, table, q):
    values = table_convert.convert_multitable(table)    
    p, code = gen_code3(llm, messages, q, values)    
    print("code:", code)
    (v, s) = exec_code(code, values)
    return  (v, s, code)

# %%
items = [i for idx, i in devdf.iterrows()]
item = items[1]
table = item['table']['table']
q = item.questions[4]
question = q['question']
#print(table, question)
r = get_answer(llm, prompt_versions.prompt_versions['V11'], table, question)
print(r[0], r[1], r[2])
# Out:
#
# ```python
# import math
#
# def run(value_list):
#     appliances = [x for x in value_list if x['category'] == 'Appliances']
#     result = sum([x['number_value'] - x['number_value'].year*1000 if x['scale'] == 'million' else (x['number_value'] - x['number_value'].year) / 1000 if x['scale'] == 'billion' else (x['number_value'] - x['number_value'].year) * 1000 if x['scale'] == 'thousand' else ((x['number_value'] - x['number_value'].year) / math.pow(10, x['scale'])) for x in appliances])
#     return result, ''
#
# value_list = [{'number_value': 1673.0, 'scale': 'million', 'category': 'Appliances'}, {'number_value': 1747.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 680.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 7821.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 685.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 682.0, 'scale': 'thousand', 'category': 'Appliances'},
#              {'number_value': 1673.0, 'scale': 'billion', 'category': 'Appliances'},
#              {'number_value': 1747.0, 'scale': 'billion', 'category': 'Appliances'}]
#
# result, _ = run(value_list)
# print(result)
# code:
# [Error]name 'run' is not defined
# [Error]name 'run' is not defined

# %%
from tqdm.notebook import tqdm as log_progress
import prompt_versions

devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')
cnt = 0
res = []
for i, item in log_progress(devdf.iterrows()):
    try:
        #if cnt == 36:
        #    break;
        #print(item['table']['uid'])
        table = item['table']['table']
        value_list = table_convert.convert_multitable(table)    
        text = '\n'.join( [p['text'] for p in item['paragraphs']])
        for q in item['questions']:        
            if q['answer_type'] == 'arithmetic' and 'table' == q['answer_from']:   
                cnt = cnt + 1
                print(q['uid'])
                _table, _q =  get_question(q['uid'])
                
                table = _table['table']
                
                #[print(r) for r in table]
                
                q = _q['question']
                print(q, end='')
                
                
                r = []
                #for i in [0,1,2]:        
                #   r.append(get_answer(llm, messages, table, q))
                
                #if r[0][0] == r[1][0]:
                #    (v, s) = r[0]
                #elif r[1][0] == r[2][0]:
                #    (v, s) = r[1]
                #elif r[0][0] == r[2][0]:
                #    (v, s) = r[0]
                #else:
                #    (v, s) = (None, None)
                    
                #(v, s, code) = get_answer(llm, messages, table, q)    
                (pred_value, pred_scale, code) = get_answer(llm, prompt_versions.prompt_versions['V18'], table, q)    
                
                if 'in millions' in text.lower() and pred_scale == '':
                    pred_scale = 'million'
                    
                if  utils.eval_predicted_value(pred_value, _q['answer']):
                    print("\033[92m Success: " + str(pred_value)+'\033[0m')
                else:    
                    print("\033[91m failure: " + str(pred_value), 'good answer: ', _q['answer'],'\033[0m' )
                
                if isinstance(pred_value, tuple) and len(pred_value) == 2:
                    print('$$$$')
                    (pred_value, pred_scale) = pred_value
                if pred_scale == "%" or pred_scale == "percentage"  :
                    pred_scale = 'percent'
                if pred_scale not in ["", 'thousand', 'million', 'billion', 'percent']:
                    print('Invalid ', pred_scale)
                    pred_scale = ""    
                #if item['table']['uid'] in res_scale and pred_scale != 'percent':
                #    pred_scale = res_scale[item['table']['uid']]
                err=""
                if isinstance(pred_value, str):
                    #print("string")
                    if  pred_value.startswith('[Error]'):
                        err = pred_value
                        (pred_value, pred_scale) = ("", "")
                                                                              
                res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, pred_value, pred_scale, _q, code, table,value_list, err))
    except Exception as e:
        s = '[Outer Exception]'+ str(e)
        print(s)
        res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, "", "", _q, "", table,"", s))
# Out:
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018?```python
# def run(value_list):
#     appliance = next((item for item in value_list if 'Appliances' in item['header1']), None)
#
#     if appliance:
#         previous_value = float(appliance['number_value']) / 1000
#         change = round(previous_value - float(appliance['number_value']), 2)
#         scale = ''
#
#         for key, val in value_list[0].items():
#             if key == 'scale':
#                 continue
#
#             if isinstance(val, dict):
#                 scale = val.get('scale', '')
#
#             elif scale:
#                 break
#
#         return round(change, 2), scale
#     else:
#         return None, ''
# ```
# code: def run(value_list):
#     appliance = next((item for item in value_list if 'Appliances' in item['header1']), None)
#
#     if appliance:
#         previous_value = float(appliance['number_value']) / 1000
#         change = round(previous_value - float(appliance['number_value']), 2)
#         scale = ''
#
#         for key, val in value_list[0].items():
#             if key == 'scale':
#                 continue
#
#             if isinstance(val, dict):
#                 scale = val.get('scale', '')
#
#             elif scale:
#                 break
#
#         return round(change, 2), scale
#     else:
#         return None, ''
#
#  failure: None good answer:  -94
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018?```python
# def run(value_list):
#     appliances_2019 = value_list[1]
#     percentage_change_2018_to_2019 = ((appliance_2019['number_value'] - appliance_2018_2019['number_value']) / appliance_2018_2019['number_value']) * 100
#     return (percentage_change_2018_to_2019, appliances_2019['scale'])
# ```
#
# ```python
# def run(value_list):
#     appliances_2019 = value_list[1]
#     percentage_change_2018_to_2019 = ((appliance_2019['number_value'] - appliance_2018_2019['number_value']) / appliance_2018_2019['number_value']) * 100
#     return (round(float(percentage_change_2018_to_2019), 2), appliances_2019.get('scale', ''))
# ```
# code: def run(value_list):
#     appliances_2019 = value_list[1]
#     percentage_change_2018_to_2019 = ((appliance_2019['number_value'] - appliance_2018_2019['number_value']) / appliance_2018_2019['number_value']) * 100
#     return (percentage_change_2018_to_2019, appliances_2019['scale'])
#
#
# def run(value_list):
#     appliances_2019 = value_list[1]
#     percentage_change_2018_to_2019 = ((appliance_2019['number_value'] - appliance_2018_2019['number_value']) / appliance_2018_2019['number_value']) * 100
#     return (round(float(percentage_change_2018_to_2019), 2), appliances_2019.get('scale', ''))
#
# [Error]name 'appliance_2019' is not defined
#  failure: [Error]name 'appliance_2019' is not defined good answer:  -12.14
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019?```python
# def run(value_list):
#     domestic = value_list[1].get('header3', 'Domestic')
#     international = value_list[2].get('header3', 'International')
#
#     percent_domestic = value_list[0].get('number_value', '') if '.' in value_list[0].get('number_value', '') else value_list[0]['number_value']
#     percent_international = value_list[1].get('number_value', '') if '.' in value_list[1].get('number_value', '') else value_list[1]['number_value']
#
#     domestic_scale = int(value_list[1].get('scale') or '000')
#     international_scale = int(value_list[2].get('scale') or '000')
#
#     percent_domestic_float = float(percent_domestic) if '.' in percent_domestic else percent_domestic
#     percent_international_float = float(percent_international) if '.' in percent_international else percent_international
#
#     return round((percent_domestic_float - percent_international_float), 2)
# ```
# code: def run(value_list):
#     domestic = value_list[1].get('header3', 'Domestic')
#     international = value_list[2].get('header3', 'International')
#
#     percent_domestic = value_list[0].get('number_value', '') if '.' in value_list[0].get('number_value', '') else value_list[0]['number_value']
#     percent_international = value_list[1].get('number_value', '') if '.' in value_list[1].get('number_value', '') else value_list[1]['number_value']
#
#     domestic_scale = int(value_list[1].get('scale') or '000')
#     international_scale = int(value_list[2].get('scale') or '000')
#
#     percent_domestic_float = float(percent_domestic) if '.' in percent_domestic else percent_domestic
#     percent_international_float = float(percent_international) if '.' in percent_international else percent_international
#
#     return round((percent_domestic_float - percent_international_float), 2)
#
# [Error]argument of type 'float' is not iterable
#  failure: [Error]argument of type 'float' is not iterable good answer:  2.1
# 4dc8be43-d8d9-4b08-9ffd-9c19012361ce
# What is the year on year percentage change in domestic discount rate between 2018 and 2019?```python
# def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and item['category'] == 'Discount rate':
#             year_change = (item['header1'].split(' ')[-2] - int(item['header1'].split(' ')[-3])) / 1000 / 365
#             return round(float(item['number_value']), 2), f"{item['scale']} thousand"
#     return None, ""
# ```
# code: def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and item['category'] == 'Discount rate':
#             year_change = (item['header1'].split(' ')[-2] - int(item['header1'].split(' ')[-3])) / 1000 / 365
#             return round(float(item['number_value']), 2), f"{item['scale']} thousand"
#     return None, ""
#
# [Error]list index out of range
#  failure: [Error]list index out of range good answer:  6.67
# 6c44a1a8-0785-43a0-90ab-7e21df2c57d9
# What is the year on year percentage change in international expected return on plan assets between 2018 and 2019?```python
# def run(value_list):
#     for item in value_list:
#         if item['category'] == 'Expected return on plan assets':
#             if item['number_value'] > 0 and item['year'] >= 2018 and item['year'] <= 2019:
#                 result = item['number_value']
#                 scale = ''
#
#                 # Remove the string containing the number from the number value
#                 start_index = len(item['header1'].replace(' Domestic', '').replace(' International', ''))
#                 end_index = start_index + item['number_value'].encode().decode().find('.')
#                 if '.' in result:
#                     whole, decimal = map(int, result.split('.')[0].split('.'))
#                     if whole > 0 and whole < 100000000:
#                         result = str(whole) + '.' + str(decimal)
#                         scale = 'billion'
#                 else:
#                     result = str(result)
#
#                 return (float(result), scale)
#     return None
# ```
# code: def run(value_list):
#     for item in value_list:
#         if item['category'] == 'Expected return on plan assets':
#             if item['number_value'] > 0 and item['year'] >= 2018 and item['year'] <= 2019:
#                 result = item['number_value']
#                 scale = ''
#
#                 # Remove the string containing the number from the number value
#                 start_index = len(item['header1'].replace(' Domestic', '').replace(' International', ''))
#                 end_index = start_index + item['number_value'].encode().decode().find('.')
#                 if '.' in result:
#                     whole, decimal = map(int, result.split('.')[0].split('.'))
#                     if whole > 0 and whole < 100000000:
#                         result = str(whole) + '.' + str(decimal)
#                         scale = 'billion'
#                 else:
#                     result = str(result)
#
#                 return (float(result), scale)
#     return None
#
# [Error]'year'
#  failure: [Error]'year' good answer:  -8.11
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes?```python
# def run(value_list):
#     def process_value(val):
#         if val['scale'] == 'million':
#             return round(val['number_value'] / 1e6, 2)
#         elif val['scale'] == 'billion':
#             return round(val['number_value'] / 1e9, 2)
#         elif val['scale'].lower() == '%':
#             return (val['number_value'] / 100) * 100
#         else:
#             return val['number_value']
#
#     # Process all values in the list and calculate the average
#     numbers = [process_value(val) for val in value_list]
#
#     # Calculate and return the average
#     average = sum(numbers) / len(numbers)
#
#     return (round(average, 2), 'million')
# ```
# code: def run(value_list):
#     def process_value(val):
#         if val['scale'] == 'million':
#             return round(val['number_value'] / 1e6, 2)
#         elif val['scale'] == 'billion':
#             return round(val['number_value'] / 1e9, 2)
#         elif val['scale'].lower() == '%':
#             return (val['number_value'] / 100) * 100
#         else:
#             return val['number_value']
#
#     # Process all values in the list and calculate the average
#     numbers = [process_value(val) for val in value_list]
#
#     # Calculate and return the average
#     average = sum(numbers) / len(numbers)
#
#     return (round(average, 2), 'million')
#
#  failure: 0.0 good answer:  172
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes?```python
# def run(value_list):
#     defined_schemes = {key['category']: key for key in value_list if 'Defined benefit schemes' in key['header1']}
#
#     def convert_value(value):
#         scale = value['scale']
#         if scale == 'million':
#             return float(value['number_value']) / 1000000
#         elif scale == 'billion':
#             return float(value['number_value']) / 1000000000
#         elif scale == '%':
#             return (float(value['number_value']) - 1) * 10**(3)
#         else:
#             raise ValueError('Unknown scale')
#
#     average Defined Benefit schemes = convert_value(sum(defined_schemes.values()) / len(defined_schemes))
#     return (round(average Defined Benefit schemes, 2), 'thousand')
# ```
# code: def run(value_list):
#     defined_schemes = {key['category']: key for key in value_list if 'Defined benefit schemes' in key['header1']}
#
#     def convert_value(value):
#         scale = value['scale']
#         if scale == 'million':
#             return float(value['number_value']) / 1000000
#         elif scale == 'billion':
#             return float(value['number_value']) / 1000000000
#         elif scale == '%':
#             return (float(value['number_value']) - 1) * 10**(3)
#         else:
#             raise ValueError('Unknown scale')
#
#     average Defined Benefit schemes = convert_value(sum(defined_schemes.values()) / len(defined_schemes))
#     return (round(average Defined Benefit schemes, 2), 'thousand')
#
# [Error]invalid syntax (<string>, line 15)
#  failure: [Error]invalid syntax (<string>, line 15) good answer:  50.5
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?```python
# def run(value_list):
#     defined_contribution_schemes = [item for item in value_list if 'Defined contribution schemes' in item['category']]
#     average_defined_contribution_schemes = sum(item['number_value'] / float(item['scale']) for item in defined_contribution_schemes) if defined_contribution_schemes else 0
#     defined_benefit_schemes = [item for item in value_list if 'Defined benefit schemes' in item['category']]
#     average_defined_benefit_schemes = sum(item['number_value'] / float(item['scale']) for item in defined_benefit_schemes) if defined_benefit_schemes else 0
#
#     difference = average_defined_contribution_schemes - average_defined_benefit_schemes
#     scale = ''
#     if 'billion' in value_list or 'million' in value_list:
#         scale = 'billion'
#     elif 'million' in value_list:
#         scale = 'million'
#
#     return (round(difference, 2), scale)
# ```
# code: def run(value_list):
#     defined_contribution_schemes = [item for item in value_list if 'Defined contribution schemes' in item['category']]
#     average_defined_contribution_schemes = sum(item['number_value'] / float(item['scale']) for item in defined_contribution_schemes) if defined_contribution_schemes else 0
#     defined_benefit_schemes = [item for item in value_list if 'Defined benefit schemes' in item['category']]
#     average_defined_benefit_schemes = sum(item['number_value'] / float(item['scale']) for item in defined_benefit_schemes) if defined_benefit_schemes else 0
#
#     difference = average_defined_contribution_schemes - average_defined_benefit_schemes
#     scale = ''
#     if 'billion' in value_list or 'million' in value_list:
#         scale = 'billion'
#     elif 'million' in value_list:
#         scale = 'million'
#
#     return (round(difference, 2), scale)
#
# [Error]could not convert string to float: 'million'
#  failure: [Error]could not convert string to float: 'million' good answer:  121.5
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019?```
# import pandas as pd
# from io import StringIO
#
# def run(value_list):
#     df = pd.DataFrame(StringIO('\n'.join(map(str, value_list))))
#
#     # Convert 'number_value' column to numeric
#     df['number_value'] = pd.to_numeric(df['number_value'], errors='coerce')
#
#     # Calculate percentage change from 2018 to 2019
#     change = (df['number_value'].shift(-1) / df['number_value']) - 1
#
#     # Convert 'scale' column to string, replace '-' with ''
#     df['scale'] = df['scale'].str.replace('-', '')
#
#     # Filter values for 'Operating loss carryforward'
#     filtered_df = df[df['category'] == 'Operating loss carryforward']
#
#     # Calculate percentage change in column 'number_value'
#     result = (filtered_df['number_value'] / filtered_df.shift(-1) - 1).mul(100).round(2)
#
#     return float(result), 'percent'
#
# ```
# code: import pandas as pd
# from io import StringIO
#
# def run(value_list):
#     df = pd.DataFrame(StringIO('\n'.join(map(str, value_list))))
#
#     # Convert 'number_value' column to numeric
#     df['number_value'] = pd.to_numeric(df['number_value'], errors='coerce')
#
#     # Calculate percentage change from 2018 to 2019
#     change = (df['number_value'].shift(-1) / df['number_value']) - 1
#
#     # Convert 'scale' column to string, replace '-' with ''
#     df['scale'] = df['scale'].str.replace('-', '')
#
#     # Filter values for 'Operating loss carryforward'
#     filtered_df = df[df['category'] == 'Operating loss carryforward']
#
#     # Calculate percentage change in column 'number_value'
#     result = (filtered_df['number_value'] / filtered_df.shift(-1) - 1).mul(100).round(2)
#
#     return float(result), 'percent'
#
#
# [Error]name 'StringIO' is not defined
#  failure: [Error]name 'StringIO' is not defined good answer:  26.82
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019?```python
# def run(value_list):
#     net_deferred_tax_asset_2019 = value_list[1]['number_value']
#     net_deferred_tax_asset_2018 = value_list[0]['number_value']
#
#     percentage_change = ((net_deferred_tax_asset_2019 - net_deferred_tax_asset_2018) / net_deferred_tax_asset_2018) * 100
#
#     return (round(percentage_change, 2), 'billion')
# ```
# code: def run(value_list):
#     net_deferred_tax_asset_2019 = value_list[1]['number_value']
#     net_deferred_tax_asset_2018 = value_list[0]['number_value']
#
#     percentage_change = ((net_deferred_tax_asset_2019 - net_deferred_tax_asset_2018) / net_deferred_tax_asset_2018) * 100
#
#     return (round(percentage_change, 2), 'billion')
#
#  failure: -21.15 good answer:  2.98
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019?```python
# def run(value_list):
#     total_assets = sum(item['number_value'] for item in value_list if 'total' not in item.get('category', {}).values()) \
#                     + sum(item['number_value'] * 1000000 for item in value_list) / 10**6
#     total_liabilities = sum(item['number_value'] if 'total' not in item.get('category', {}).values() else item['number_value'] * 10**6 for item in value_list) \
#                        + sum(item['number_value'] * 1000000 for item in value_list) / 10**6
#     return round(total_assets / total_liabilities, 2)
# ```
# code: def run(value_list):
#     total_assets = sum(item['number_value'] for item in value_list if 'total' not in item.get('category', {}).values()) \
#                     + sum(item['number_value'] * 1000000 for item in value_list) / 10**6
#     total_liabilities = sum(item['number_value'] if 'total' not in item.get('category', {}).values() else item['number_value'] * 10**6 for item in value_list) \
#                        + sum(item['number_value'] * 1000000 for item in value_list) / 10**6
#     return round(total_assets / total_liabilities, 2)
#
# [Error]'str' object has no attribute 'values'
#  failure: [Error]'str' object has no attribute 'values' good answer:  2.93
# 263d03ec-83d2-48df-8376-1a72167798f7
# What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?```python
# def run(value_list):
#     total_property_plant_and_equipment = value_list[0]['number_value']
#     total_assets = sum(value['number_value'] for value in value_list)
#
#     proportion = (total_property_plant_and_equipment / total_assets) * 100
#
#     # Fix the scale to ' billion'
#     if 'scale' in value_list[0]:
#         if value_list[0]['scale'].endswith('billion'):
#             return round(proportion, 2), ''
#         elif value_list[0]['scale'].endswith('million'):
#             return round(proportion, 2), ''
#         else:
#             return round(proportion, 2)
#     else:
#         return round(proportion, 2)
# ```
# code: def run(value_list):
#     total_property_plant_and_equipment = value_list[0]['number_value']
#     total_assets = sum(value['number_value'] for value in value_list)
#
#     proportion = (total_property_plant_and_equipment / total_assets) * 100
#
#     # Fix the scale to ' billion'
#     if 'scale' in value_list[0]:
#         if value_list[0]['scale'].endswith('billion'):
#             return round(proportion, 2), ''
#         elif value_list[0]['scale'].endswith('million'):
#             return round(proportion, 2), ''
#         else:
#             return round(proportion, 2)
#     else:
#         return round(proportion, 2)
#
# [Outer Exception]cannot unpack non-iterable float object
# a4f782f1-de3b-47a3-87af-1cb33c112b39
# What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?```python
# def run(value_list):
#     """
#     Calculate percentage change in Value added tax receivables, net, noncurrent.
#
#     Args:
#         value_list (list): List of annotated values.
#
#     Returns:
#         tuple: (number, scale)
#     """
#
#     # Unpack the list to access the individual dictionaries
#     num_values = value_list[::2]  # Values for years
#     scale_values = value_list[1::2]  # Scales
#
#     # Calculate the percentage change in Value added tax receivables, net, noncurrent (Note 3)
#     percent_change_value = ((num_values[0]['number_value'] - num_values[-1]['number_value']) /
#                              num_values[-1]['number_value']) * 100
#     percent_change_scale = scale_values[0].replace(',', '') if len(scale_values) > 0 else ''
#
#     # Return the result as a tuple (number, scale)
#     return round(percent_change_value, 2), percent_change_scale
# ```
# code: def run(value_list):
#     """
#     Calculate percentage change in Value added tax receivables, net, noncurrent.
#
#     Args:
#         value_list (list): List of annotated values.
#
#     Returns:
#         tuple: (number, scale)
#     """
#
#     # Unpack the list to access the individual dictionaries
#     num_values = value_list[::2]  # Values for years
#     scale_values = value_list[1::2]  # Scales
#
#     # Calculate the percentage change in Value added tax receivables, net, noncurrent (Note 3)
#     percent_change_value = ((num_values[0]['number_value'] - num_values[-1]['number_value']) /
#                              num_values[-1]['number_value']) * 100
#     percent_change_scale = scale_values[0].replace(',', '') if len(scale_values) > 0 else ''
#
#     # Return the result as a tuple (number, scale)
#     return round(percent_change_value, 2), percent_change_scale
#
# [Error]'dict' object has no attribute 'replace'
#  failure: [Error]'dict' object has no attribute 'replace' good answer:  14.07
# dc5e217a-a7b3-4fc9-ac0f-13d328f26b20
# What is the 2019 average free cash flow?```python
# def run(value_list):
#     if 'scale' in value_list[0]:
#         scale = value_list[0]['scale']
#         average = (value_list[-1]['number_value'] - value_list[0]['number_value']) / (len(value_list) - 1)
#         return round(average, 2), scale
#     else:
#         return None, ''
# ```
# code: def run(value_list):
#     if 'scale' in value_list[0]:
#         scale = value_list[0]['scale']
#         average = (value_list[-1]['number_value'] - value_list[0]['number_value']) / (len(value_list) - 1)
#         return round(average, 2), scale
#     else:
#         return None, ''
#
#  failure: -252.7 good answer:  4227.5
# 7cd3aedf-1291-4fea-bc9d-a25c65727b7b
# What is the 2018 average free cash flow?```python
# def run(value_list):
#     def extract_scale(value):
#         if value == 'million':
#             return 'million'
#         elif value.endswith('Billion'):
#             return 'billion'
#         else:
#             return ''
#
#     average_free_cash_flow = sum(
#         [value['number_value'] * scale
#          for value, scale in zip(value_list, map(extract_scale, value_list)) if scale != '']
#     ) / len(value_list)
#
#     return (round(average_free_cash_flow, 2), extract_scale(str(average_free_cash_flow)))
# ```
# code: def run(value_list):
#     def extract_scale(value):
#         if value == 'million':
#             return 'million'
#         elif value.endswith('Billion'):
#             return 'billion'
#         else:
#             return ''
#
#     average_free_cash_flow = sum(
#         [value['number_value'] * scale
#          for value, scale in zip(value_list, map(extract_scale, value_list)) if scale != '']
#     ) / len(value_list)
#
#     return (round(average_free_cash_flow, 2), extract_scale(str(average_free_cash_flow)))
#
# [Error]'dict' object has no attribute 'endswith'
#  failure: [Error]'dict' object has no attribute 'endswith' good answer:  3680
# 22e20f25-669a-46b9-8779-2768ba391955
# What is the change between 2018 and 2019 average free cash flow?```python
# def run(value_list):
#     average_free_cash_flow_2018 = sum(annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)') / len([annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)'])
#     average_free_cash_flow_2019 = sum(annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)') / len([annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)'])
#     return (round((average_free_cash_flow_2019 - average_free_cash_flow_2018) * 100, 2), '')
# ```
# code: def run(value_list):
#     average_free_cash_flow_2018 = sum(annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)') / len([annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)'])
#     average_free_cash_flow_2019 = sum(annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)') / len([annotated_value for annotated_value in value_list if annotated_value['category'] == 'Free cash flow (pre-spectrum)'])
#     return (round((average_free_cash_flow_2019 - average_free_cash_flow_2018) * 100, 2), '')
#
# [Error]unsupported operand type(s) for +: 'int' and 'dict'
#  failure: [Error]unsupported operand type(s) for +: 'int' and 'dict' good answer:  547.5
# a983501d-2eec-486d-9661-e520c7c8af5e
# What was the average difference between EBITDA and underlying EBITDA for both FYs?```python
# def run(value_list):
#     """
#     Calculate the average difference between EBITDA and underlying EBITDA for both FYs.
#
#     Args:
#         value_list (list): A list of dictionaries containing annotated values.
#
#     Returns:
#         tuple: A tuple containing a float number and a string scale.
#     """
#
#     # Extract the numbers
#     numbers = [value['number_value'] for value in value_list]
#
#     # Calculate the differences
#     diff1 = numbers[0] - numbers[-1]
#     diff2 = numbers[0] - numbers[1]
#
#     # Calculate the average difference
#     avg_diff = (diff1 + diff2) / 2
#
#     return round(avg_diff, 2), 'billion'
# ```
# code: def run(value_list):
#     """
#     Calculate the average difference between EBITDA and underlying EBITDA for both FYs.
#
#     Args:
#         value_list (list): A list of dictionaries containing annotated values.
#
#     Returns:
#         tuple: A tuple containing a float number and a string scale.
#     """
#
#     # Extract the numbers
#     numbers = [value['number_value'] for value in value_list]
#
#     # Calculate the differences
#     diff1 = numbers[0] - numbers[-1]
#     diff2 = numbers[0] - numbers[1]
#
#     # Calculate the average difference
#     avg_diff = (diff1 + diff2) / 2
#
#     return round(avg_diff, 2), 'billion'
#
#  failure: -13156.5 good answer:  3728
# 64c902c6-f426-4432-84b3-c10b3065716f
# What was the difference in net profit between both FYs?```python
# def run(value_list):
#     """
#     Calculate the difference in net profit between FYs.
#
#     Args:
#         value_list (list): List of dictionaries containing annotated values.
#             Each dictionary must have 'number_value', 'scale' and 'category'.
#
#     Returns:
#         tuple: Tuple of two float numbers with accuracy to two decimal places.
#     """
#
#     # Initialize variables
#     difference = 0.0
#
#     # Iterate through the list of values
#     for value in value_list:
#         # Check if category is 'Net profit/(loss) after tax'
#         if value['category'] == 'Net profit/(loss) after tax':
#             # Extract number_value and scale
#             number_value = float(value['number_value'])
#             scale = value['scale']
#
#             # Apply the difference in net profit formula based on scale
#             if scale.endswith('thousand'):
#                 difference += number_value * 10.0
#             elif scale.endswith('%'):
#                 difference += (number_value / 100) * 10.0
#             elif scale == 'billion':
#                 difference += number_value * 1000000.0
#             elif scale == '%':
#                 difference += (number_value / 100.0) * 10.0
#
#     # Round the result to two decimal places
#     difference = round(difference, 2)
#
#     return difference, ''
# ```
# code: def run(value_list):
#     """
#     Calculate the difference in net profit between FYs.
#
#     Args:
#         value_list (list): List of dictionaries containing annotated values.
#             Each dictionary must have 'number_value', 'scale' and 'category'.
#
#     Returns:
#         tuple: Tuple of two float numbers with accuracy to two decimal places.
#     """
#
#     # Initialize variables
#     difference = 0.0
#
#     # Iterate through the list of values
#     for value in value_list:
#         # Check if category is 'Net profit/(loss) after tax'
#         if value['category'] == 'Net profit/(loss) after tax':
#             # Extract number_value and scale
#             number_value = float(value['number_value'])
#             scale = value['scale']
#
#             # Apply the difference in net profit formula based on scale
#             if scale.endswith('thousand'):
#                 difference += number_value * 10.0
#             elif scale.endswith('%'):
#                 difference += (number_value / 100) * 10.0
#             elif scale == 'billion':
#                 difference += number_value * 1000000.0
#             elif scale == '%':
#                 difference += (number_value / 100.0) * 10.0
#
#     # Round the result to two decimal places
#     difference = round(difference, 2)
#
#     return difference, ''
#
#  failure: -31824.8 good answer:  -16458
# 91812b92-5e94-414f-a447-4622aa3c2d10
# What was the average dividend yield for the 3 years from 2017 to 2019?```python
# def run(value_list):
#     """
#     Calculate the average dividend yield for the given years.
#
#     Parameters:
#     value_list (list): A list of annotated values.
#
#     Returns:
#     tuple: A tuple containing a float number and a string scale.
#     """
#
#     # Filter values for the 3 years from 2017 to 2019
#     three_years = [value for value in value_list if '2017' <= value['header1'] <= '2019']
#
#     # If there are no values, return (0.00, '')
#     if not three_years:
#         return (0.00, '')
#
#     # Calculate the dividend yield as a percentage
#     avg_dividend_yield_percent = sum(value['number_value'] * 100 / value_list[0]['number_value'] for value in three_years) / len(three_years)
#
#     # Format the result with thousand, million, billion scale and two decimal places accuracy
#     if 'billion' in value_list[0]['scale']:
#         avg_dividend_yield = f"{avg_dividend_yield_percent:.2f} billion"
#     elif 'million' in value_list[0]['scale']:
#         avg_dividend_yield = f"{avg_dividend_yield_percent / 1000:.2f} million"
#     else:
#         avg_dividend_yield = f"{avg_dividend_yield_percent:.2f}"
#
#     return (float(avg_dividend_yield), '')
# ```
# code: def run(value_list):
#     """
#     Calculate the average dividend yield for the given years.
#
#     Parameters:
#     value_list (list): A list of annotated values.
#
#     Returns:
#     tuple: A tuple containing a float number and a string scale.
#     """
#
#     # Filter values for the 3 years from 2017 to 2019
#     three_years = [value for value in value_list if '2017' <= value['header1'] <= '2019']
#
#     # If there are no values, return (0.00, '')
#     if not three_years:
#         return (0.00, '')
#
#     # Calculate the dividend yield as a percentage
#     avg_dividend_yield_percent = sum(value['number_value'] * 100 / value_list[0]['number_value'] for value in three_years) / len(three_years)
#
#     # Format the result with thousand, million, billion scale and two decimal places accuracy
#     if 'billion' in value_list[0]['scale']:
#         avg_dividend_yield = f"{avg_dividend_yield_percent:.2f} billion"
#     elif 'million' in value_list[0]['scale']:
#         avg_dividend_yield = f"{avg_dividend_yield_percent / 1000:.2f} million"
#     else:
#         avg_dividend_yield = f"{avg_dividend_yield_percent:.2f}"
#
#     return (float(avg_dividend_yield), '')
#
#  failure: 176.51 good answer:  1.57
# 29b63db7-4925-4629-b108-49bbb27fb565
# What was the average risk-free interest rate over the 3 year period from 2017 to 2019?```python
# def run(value_list):
#     risk_free_interest_rates = [item['number_value'] for item in value_list if 'risk-free interest rate' in item.get('category', '').lower()]
#
#     # Check for missing values and replace with a default
#     risk_free_interest_rates += ['0.00000' for _ in range(len(value_list) - len(risk_free_interest_rates))]
#
#     # Find the maximum length to determine scale
#     max_scale_length = max(len(scale) for item in value_list for scale in (item.get('scale', ''),))
#
#     # Calculate the average risk-free interest rate
#     average_rfr = sum(risk_free_interest_rates) / len(risk_free_interest_rates)
#
#     return round(average_rfr, 2), ''
# ```
# code: def run(value_list):
#     risk_free_interest_rates = [item['number_value'] for item in value_list if 'risk-free interest rate' in item.get('category', '').lower()]
#
#     # Check for missing values and replace with a default
#     risk_free_interest_rates += ['0.00000' for _ in range(len(value_list) - len(risk_free_interest_rates))]
#
#     # Find the maximum length to determine scale
#     max_scale_length = max(len(scale) for item in value_list for scale in (item.get('scale', ''),))
#
#     # Calculate the average risk-free interest rate
#     average_rfr = sum(risk_free_interest_rates) / len(risk_free_interest_rates)
#
#     return round(average_rfr, 2), ''
#
# [Error]unsupported operand type(s) for +: 'float' and 'str'
#  failure: [Error]unsupported operand type(s) for +: 'float' and 'str' good answer:  1.9
# 6100c476-160a-4f1e-bfc1-a16f4cc18b52
# What was the increase / (decrease) in the cost from 2018 to 2019?```python
# def run(value_list):
#     numbers = [v['number_value'] for v in value_list]
#     increases = [num / prev_num if num != prev_num else 'NA' for prev_num, num in zip(numbers, numbers[1:]) if num > prev_num]
#     decreases = ['NA' if num < prev_num else num for prev_num, num in zip(numbers, numbers[1:]) if num < prev_num]
#
#     if increases:
#         return float(max(increases)), 'millions'
#     elif decreases:
#         return lead_decimal(float(decreases)), 'per thousand'
#     else:
#         scale = 'million' if all(scale == 'million' for v in value_list) else 'million'
#         return lead_decimal(numbers[0]), scale
#
# def lead_decimal(num):
#     return float(str(num).replace('.', '').rstrip('0').lstrip(''))
# ```
#
# This function first separates the numbers into two lists, `increases` and `decreases`, based on whether they are increasing or decreasing. It then checks which list is not empty (in case there's a tie between the two), and returns that value as the lead decimal number.
#
# The function then uses the `float()` function to convert both lists into floats with no leading zeros, removes any trailing zeros using `str()`, and rstrip characters.
#
# Finally, it checks if all numbers are in million scale, and sets the scale string accordingly.
# code: def run(value_list):
#     numbers = [v['number_value'] for v in value_list]
#     increases = [num / prev_num if num != prev_num else 'NA' for prev_num, num in zip(numbers, numbers[1:]) if num > prev_num]
#     decreases = ['NA' if num < prev_num else num for prev_num, num in zip(numbers, numbers[1:]) if num < prev_num]
#
#     if increases:
#         return float(max(increases)), 'millions'
#     elif decreases:
#         return lead_decimal(float(decreases)), 'per thousand'
#     else:
#         scale = 'million' if all(scale == 'million' for v in value_list) else 'million'
#         return lead_decimal(numbers[0]), scale
#
# def lead_decimal(num):
#     return float(str(num).replace('.', '').rstrip('0').lstrip(''))
#
#  failure: 11.508474576271187 good answer:  18
# Invalid  millions
# a81f1322-e74f-4e3c-a6cf-4b8d25d01cf5
# What is the average Selling, general and administrative?```python
# def run(value_list):
#     avg = sum(item['number_value'] for item in value_list) / len(value_list)
#     scale = 'million'
#     if item['scale'] == 'percent':
#         scale = ''
#     elif item['scale'] == 'billion':
#         scale = 'billions'
#     return (round(avg, 2), scale)
# ```
# code: def run(value_list):
#     avg = sum(item['number_value'] for item in value_list) / len(value_list)
#     scale = 'million'
#     if item['scale'] == 'percent':
#         scale = ''
#     elif item['scale'] == 'billion':
#         scale = 'billions'
#     return (round(avg, 2), scale)
#
# [Error]'scale'
#  failure: [Error]'scale' good answer:  399.33
# f7cac790-05ae-4a55-a41d-836a6b415f88
# What is the percentage increase / (decrease) of Research, development and engineering from 2018 to 2019?```python
# import math
#
# def run(value_list):
#     if value_list:
#         research_2019 = next((v['number_value'] for v in value_list if v['category'] == 'Research, development and engineering'), 0)
#         research_2018 = next((v['number_value'] for v in value_list if v['category'] == 'Research, development and engineering'), 0)
#
#         percentage_increase = (research_2019 / research_2018) * 100 if research_2018 != 0 else 0
#     else:
#         return 0.00, ''
#
#     # scale
#     if value_list[0]['scale'] == 'million':
#         percentage_increase /= 1e6
#     elif value_list[0]['scale'] == 'billion':
#         percentage_increase /= 1e9
#     elif value_list[0]['scale'] == '%':
#         percentage_increase = percentage_increase / 100
#
#     return round(percentage_increase, 2), ''
# ```
# code: import math
#
# def run(value_list):
#     if value_list:
#         research_2019 = next((v['number_value'] for v in value_list if v['category'] == 'Research, development and engineering'), 0)
#         research_2018 = next((v['number_value'] for v in value_list if v['category'] == 'Research, development and engineering'), 0)
#
#         percentage_increase = (research_2019 / research_2018) * 100 if research_2018 != 0 else 0
#     else:
#         return 0.00, ''
#
#     # scale
#     if value_list[0]['scale'] == 'million':
#         percentage_increase /= 1e6
#     elif value_list[0]['scale'] == 'billion':
#         percentage_increase /= 1e9
#     elif value_list[0]['scale'] == '%':
#         percentage_increase = percentage_increase / 100
#
#     return round(percentage_increase, 2), ''
#
#  failure: 0.0 good answer:  88.06
# 65ec782c-691e-45df-b541-caecb85154ff
# What was the change in Capital redemption reserve in 2019 from 2018?```python
# def run(value_list):
#     for item in value_list:
#         if 'recovery' in item['category'] and ('net' in item['header2'].lower() or 'retained' in item['header2'].lower()):
#             return (item['number_value'], 'million')
#
#     raise ValueError("No change in Capital redemption reserve found")
# ```
# code: def run(value_list):
#     for item in value_list:
#         if 'recovery' in item['category'] and ('net' in item['header2'].lower() or 'retained' in item['header2'].lower()):
#             return (item['number_value'], 'million')
#
#     raise ValueError("No change in Capital redemption reserve found")
#
# [Error]No change in Capital redemption reserve found
#  failure: [Error]No change in Capital redemption reserve found good answer:  0.2
# 94916f79-4b6d-487f-8fa2-39f81a085760
# What was the percentage change in Capital redemption reserve in 2019 from 2018?```python
# def run(value_list):
#     """
#     Calculate the percentage change in Capital redemption reserve from 2018 to 2019.
#
#     Args:
#         value_list (list): A list of annotated values representing the historical data.
#
#     Returns:
#         tuple: A tuple containing the numerical result and its scale. The result is a float with accuracy to two decimal places.
#     """
#     # Find the Capital redemption reserve values for 2018 and 2019
#     capital_redeemed_in_2018 = [value['number_value'] for value in value_list if value['category'] == 'Capital redemption reserve']
#     capital_redeemed_in_2019 = [value['number_value'] for value in value_list if value['category'] == 'Capital redemption reserve']
#
#     # Calculate the difference between 2019 and 2018
#     difference = capital_redeemed_in_2019[0] - capital_redeemed_in_2018[0]
#
#     # Calculate the percentage change
#     percentage_change = (difference / capital_redeemed_in_2018[0]) * 100
#
#     # Return the result and its scale as a tuple
#     return round(percentage_change, 2), 'percent'
# ```
# code: def run(value_list):
#     """
#     Calculate the percentage change in Capital redemption reserve from 2018 to 2019.
#
#     Args:
#         value_list (list): A list of annotated values representing the historical data.
#
#     Returns:
#         tuple: A tuple containing the numerical result and its scale. The result is a float with accuracy to two decimal places.
#     """
#     # Find the Capital redemption reserve values for 2018 and 2019
#     capital_redeemed_in_2018 = [value['number_value'] for value in value_list if value['category'] == 'Capital redemption reserve']
#     capital_redeemed_in_2019 = [value['number_value'] for value in value_list if value['category'] == 'Capital redemption reserve']
#
#     # Calculate the difference between 2019 and 2018
#     difference = capital_redeemed_in_2019[0] - capital_redeemed_in_2018[0]
#
#     # Calculate the percentage change
#     percentage_change = (difference / capital_redeemed_in_2018[0]) * 100
#
#     # Return the result and its scale as a tuple
#     return round(percentage_change, 2), 'percent'
#
#  failure: 0.0 good answer:  40
# bbe335ff-414f-48b3-8126-5a2c7c505de3
# How much was the average operating income from 2015 to 2019?```
# def run(value_list):
#     total_operating_income = sum([item['number_value'] for item in value_list if 'Operating income' in item['category']])
#     scale = [value.strip(' million').replace(',', '') for value in value_list if 'Operating income' in value['category']]
#
#     if not scale:
#         return 0, ''
#     elif scale == ['million']:
#         return round(total_operating_income / len(value_list), 2)
#     elif scale == ['billion']:
#         return round(total_operating_income / 1e9, 2)
#     elif scale == ['percent']:
#         return round((total_operating_income / len(value_list)) * 100, 2)
#     else:
#         return total_operating_income
# ```
# code: def run(value_list):
#     total_operating_income = sum([item['number_value'] for item in value_list if 'Operating income' in item['category']])
#     scale = [value.strip(' million').replace(',', '') for value in value_list if 'Operating income' in value['category']]
#
#     if not scale:
#         return 0, ''
#     elif scale == ['million']:
#         return round(total_operating_income / len(value_list), 2)
#     elif scale == ['billion']:
#         return round(total_operating_income / 1e9, 2)
#     elif scale == ['percent']:
#         return round((total_operating_income / len(value_list)) * 100, 2)
#     else:
#         return total_operating_income
#
# [Error]'dict' object has no attribute 'strip'
#  failure: [Error]'dict' object has no attribute 'strip' good answer:  13237.4
# ef274d2b-fbd6-4e9f-95f9-79b37827d91c
# What was the total expenses for Oracle in 2018?```python
# def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and 'scale' in item:
#             if item['scale'] == 'million':
#                 return (item['number_value'], 'million')
#             elif item['scale'] == 'billion':
#                 return (item['number_value'] / 1000000, 'billlion')
#             elif item['scale'] == '%':
#                 return (item['number_value'] / 100, 'percent')
#     raise ValueError("No expenses found in the value list")
# ```
# code: def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and 'scale' in item:
#             if item['scale'] == 'million':
#                 return (item['number_value'], 'million')
#             elif item['scale'] == 'billion':
#                 return (item['number_value'] / 1000000, 'billlion')
#             elif item['scale'] == '%':
#                 return (item['number_value'] / 100, 'percent')
#     raise ValueError("No expenses found in the value list")
#
#  failure: 39506.0 good answer:  35796
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492
# What were the total Assets as reported?```python
# def run(value_list):
#     total_assets = sum(val['number_value'] for val in value_list if 'As of February 28, 2019' in str(val) and 'Assets' in val['header1'])
#     return (round(total_assets, 2), 'million')
# ```
#
# In this function, we iterate through each item in the `value_list` and sum up the `number_value` only if it is present in the string `'As of February 28, 2019'` and contains the key `'Assets'`. This ensures that we include all items with reported assets. The result is then rounded to two decimal places and returned as a tuple.
# code: def run(value_list):
#     total_assets = sum(val['number_value'] for val in value_list if 'As of February 28, 2019' in str(val) and 'Assets' in val['header1'])
#     return (round(total_assets, 2), 'million')
#
#  failure: 118370.0 good answer:  64509
# bd2d81eb-46fc-4e62-908d-aebfccf46246
# What were the total Liabilities and Stockholders' Equity as reported?```python
# def run(value_list):
#     total_liabilities_and_stockholders_equity = sum(
#         [
#             value['number_value']
#             for value in value_list if 'Liabilities and Stockholders' in value['category'] else []
#             for _ in range(2)
#         ]
#     )
#     return (total_liabilities_and_stockholders_equity / 1000, "")
# ```
# code: def run(value_list):
#     total_liabilities_and_stockholders_equity = sum(
#         [
#             value['number_value']
#             for value in value_list if 'Liabilities and Stockholders' in value['category'] else []
#             for _ in range(2)
#         ]
#     )
#     return (total_liabilities_and_stockholders_equity / 1000, "")
#
# [Error]invalid syntax (<string>, line 5)
#  failure: [Error]invalid syntax (<string>, line 5) good answer:  62740
# 010df393-a62e-408d-888a-045a4e435e6a
# What is the difference in amount between Deferred Revenue and Other non-current liabilities as reported?```python
# def run(value_list):
#     def convert_scale(scales):
#         conversions = {
#             'b': 1e9,
#             'm': 1e6,
#             'g': 1e3,
#             't': 1,
#             '%': 0.01
#         }
#         for key, value in scales.items():
#             if isinstance(value, str) and value in conversions:
#                 scales[key] = int(float(value) * conversions[value])
#         return scales
#
#     deferred_revenue = [float(x['number_value']) for x in value_list if x['category'] == 'Deferred revenue (2)']
#     non_current_liabilities = [float(x['number_value']) for x in value_list if x['category'] == 'Other non-current liabilities (2)']
#
#     scales = convert_scale({
#         'Deferred Revenue': deferred_revenue,
#         'Other non-current Liabilities': non_current_liabilities
#     })
#
#     return (sum(scales.values()) - sum(scales.values()), '')
# ```
# code: def run(value_list):
#     def convert_scale(scales):
#         conversions = {
#             'b': 1e9,
#             'm': 1e6,
#             'g': 1e3,
#             't': 1,
#             '%': 0.01
#         }
#         for key, value in scales.items():
#             if isinstance(value, str) and value in conversions:
#                 scales[key] = int(float(value) * conversions[value])
#         return scales
#
#     deferred_revenue = [float(x['number_value']) for x in value_list if x['category'] == 'Deferred revenue (2)']
#     non_current_liabilities = [float(x['number_value']) for x in value_list if x['category'] == 'Other non-current liabilities (2)']
#
#     scales = convert_scale({
#         'Deferred Revenue': deferred_revenue,
#         'Other non-current Liabilities': non_current_liabilities
#     })
#
#     return (sum(scales.values()) - sum(scales.values()), '')
#
# [Error]unsupported operand type(s) for +: 'int' and 'list'
#  failure: [Error]unsupported operand type(s) for +: 'int' and 'list' good answer:  14212
# 58adf6c4-41ae-4f3f-84cb-cf3469a80ce4
# What was the percentage change in Total Other operating expenses between 2018 and 2019?```python
# def run(value_list):
#     total_other_expenses = sum(item['number_value'] for item in value_list if item['category'] == 'Total Other operating expenses')
#     percentage_change = (total_other_expenses / value_list[0]['number_value']) * 100 if len(value_list) > 1 else 0
#     return float(percentage_change), ''
# ```
# code: def run(value_list):
#     total_other_expenses = sum(item['number_value'] for item in value_list if item['category'] == 'Total Other operating expenses')
#     percentage_change = (total_other_expenses / value_list[0]['number_value']) * 100 if len(value_list) > 1 else 0
#     return float(percentage_change), ''
#
#  failure: 993.2059447983013 good answer:  -67.6
# 79f06004-f4fc-4e82-a9fe-3c389a2f81b6
# What was the change in the statutory federal income tax rate from 2018 to 2019?```
# def run(value_list):
#     values = [item['number_value'] for item in value_list if 'scale' in item]
#     scale = [item['scale'] for item in value_list if 'scale' in item]
#
#     change = (values[0] - values[-1]) / 10000
#     tax_scale = scale[0].replace(",", "")
#
#     return float(change), tax_scale
# ```
# code: def run(value_list):
#     values = [item['number_value'] for item in value_list if 'scale' in item]
#     scale = [item['scale'] for item in value_list if 'scale' in item]
#
#     change = (values[0] - values[-1]) / 10000
#     tax_scale = scale[0].replace(",", "")
#
# ...
# ]
#
# print(run VALUE_LIST)
# ```
# code: def run(value_list):
#     non_vested_2018 = [item['number_value'] for item in value_list if 'Non-vested at December 31, 2018' in item['category']]
#     non_vested_2019 = [item['number_value'] for item in value_list if 'Non-vested at December 31, 2019' in item['category']]
#
#     total_non_vested_2018 = sum(non_vested_2018)
#     total_non_vested_2019 = sum(non_vested_2019)
#
#     forfeited_percentage = ((non_vested_2018[0] / (total_non_vested_2018 + non_vested_2019)) * 100).quantize(2, rounding='round half away from zero')
#
#     return float(forestitten_percentage), 'billion'
#
# # Example usage
# VALUE_LIST = [
#     {'number_value': 1187586.0, 'scale': '', 'category': 'Non-vested at December 31, 2018', 'header1': 'Shares', 'header2': 'Non-vested awards'},
#     {'number_value': 41.12, 'scale': '', 'category': 'Non-vested at December 31, 2018', 'header1': 'Weighted-Average Grant Date Fair Value', 'header2': 'Non-vested awards'},
#     {'number_value': 473550.0, 'scale': '', 'category': 'Granted', 'header1': 'Shares', 'header2': 'Non-vested awards'},
#     {'number_value': 53.53, 'scale': '', 'category': 'Granted', 'header1': 'Weighted-Average Grant Date Fair Value', 'header2': 'Non-vested awards'},
#     {'number_value': -365223.0, 'scale': '', 'category': 'Vested', 'header1': 'Shares', 'header2': 'Non-vested awards'},
#     {'number_value': 41.83, 'scale': '', 'category': 'Vested', 'header1': 'Weighted-Average Grant Date Fair Value', 'header2': 'Non-vested awards'},
#     {'number_value': -12632.0, 'scale': '', 'category': 'Forfeited', 'header1': 'Shares', 'header2': 'Non-vested awards'},
#     {'number_value': 50.49, 'scale': '', 'category': 'Forfeited', 'header1': 'Weighted-Average Grant Date Fair Value', 'header2': 'Non-vested awards'},
#     {'number_value': 1283281.0, 'scale': '', 'category': 'Non-vested at December 31, 2019', 'header1': 'Shares', 'header2': 'Non-vested awards'},
#     {'number_value': 45.4, 'scale': '', 'category': 'Non-vested at December 31, 2019', 'header1': 'Weighted-Average Grant Date Fair Value', 'header2': 'Non-vested awards'}
# ]
#
# print(run VALUE_LIST)
#
# [Error]invalid syntax (<string>, line 26)
#  failure: [Error]invalid syntax (<string>, line 26) good answer:  0.98
# c8ed0bf6-60c5-41e2-97e3-5ece54a1349b
# What is the change in total personnel expenses from 2018 to 2019?```python
# def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and 'scale' in item:
#             scale = item['scale']
#         elif 'number_value' in item and 'category' in item and 'header1' in item:
#             number_value = item['number_value']
#             scale = ''
#         else:
#             continue
#
#         # Calculate percentage
#         if 'percent' in item or 'percentage' in item:
#             total_expenses = value_list[0]['number_value']
#             base = float(number_value)
#             percentage = (float(item['number_value']) / float(total_expenses)) * 100
#             result_number = round(float(base) + percentage, 2)
#
#         # Calculate change
#         if 'percent' in item or 'percentage' in item:
#             total_expenses = value_list[0]['number_value']
#             base = float(number_value)
#             percentage = (float(item['number_value']) / float(total_expenses)) * 100
#             result_number = round(float(base) - percentage, 2)
#
#         # Calculate absolute change
#         if 'percent' in item or 'percentage' in item:
#             total_expenses = value_list[0]['number_value']
#             base = float(number_value)
#             percentage = (float(item['number_value']) / float(total_expenses)) * 100
#             result_number = round(float(base) - float(percentage), 2)
#
#         # Determine scale
#         if 'scale' in item:
#             scale = item['scale']
#         elif 'category' in item and 'header1' in item:
#             category = item['category']
#             scales = {
#                 'Wages and salaries': 'thousand',
#                 'Social security': 'million',
#                 'Pension expenses': 'billion',
#                 'Share-based payment expenses': 'billion'
#             }
#             if category not in scales or len(scales[category]) == 0:
#                 scale = ''
#             else:
#                 scale = scales[category]
#         elif 'category' in item and 'header1' in item:
#             category = item['category']
#             scales = {
#                 'Wages and salaries': 'thousand',
#                 'Social security': 'million',
#                 'Pension expenses': 'billion'
#             }
#             if category not in scales or len(scales[category]) == 0:
#                 scale = ''
#             else:
#                 scale = scales[category]
#
#         result_number = f'{result_number:.2f}'
#
#     return (result_number, scale)
# ```
# code: def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and 'scale' in item:
#             scale = item['scale']
#         elif 'number_value' in item and 'category' in item and 'header1' in item:
#             number_value = item['number_value']
#             scale = ''
#         else:
#             continue
#
#         # Calculate percentage
#         if 'percent' in item or 'percentage' in item:
#             total_expenses = value_list[0]['number_value']
#             base = float(number_value)
#             percentage = (float(item['number_value']) / float(total_expenses)) * 100
#             result_number = round(float(base) + percentage, 2)
#
#         # Calculate change
#         if 'percent' in item or 'percentage' in item:
#             total_expenses = value_list[0]['number_value']
#             base = float(number_value)
#             percentage = (float(item['number_value']) / float(total_expenses)) * 100
#             result_number = round(float(base) - percentage, 2)
#
#         # Calculate absolute change
#         if 'percent' in item or 'percentage' in item:
#             total_expenses = value_list[0]['number_value']
#             base = float(number_value)
#             percentage = (float(item['number_value']) / float(total_expenses)) * 100
#             result_number = round(float(base) - float(percentage), 2)
#
#         # Determine scale
#         if 'scale' in item:
#             scale = item['scale']
#         elif 'category' in item and 'header1' in item:
#             category = item['category']
#             scales = {
#                 'Wages and salaries': 'thousand',
#                 'Social security': 'million',
#                 'Pension expenses': 'billion',
#                 'Share-based payment expenses': 'billion'
#             }
#             if category not in scales or len(scales[category]) == 0:
#                 scale = ''
#             else:
#                 scale = scales[category]
#         elif 'category' in item and 'header1' in item:
#             category = item['category']
#             scales = {
#                 'Wages and salaries': 'thousand',
#                 'Social security': 'million',
#                 'Pension expenses': 'billion'
#             }
#             if category not in scales or len(scales[category]) == 0:
#                 scale = ''
#             else:
#                 scale = scales[category]
#
#         result_number = f'{result_number:.2f}'
#
#     return (result_number, scale)
#
# [Error]local variable 'result_number' referenced before assignment
#  failure: [Error]local variable 'result_number' referenced before assignment good answer:  39224
# 4cdc8b2e-e3ea-4c36-bbda-7c409a84cc78
# What is the percentage change in total personnel expenses from 2018 to 2019?```python
# def run(value_list):
#     total_expenses_2018 = sum(float(v['number_value'] * v['scale']) for v in value_list if v['category'] == 'Pension expenses' or v['category'] == 'Share-based payment expenses' for s in v.get('scale', '') if s.strip() != '0'))
#     total_expenses_2019 = sum(float(v['number_value'] * v['scale']) for v in value_list if v['category'] == 'Pension expenses' or v['category'] == 'Share-based payment expenses' for s in v.get('scale', '') if s.strip() != '0')
#     percentage_change = round(((total_expenses_2019 - total_expenses_2018) / total_expenses_2018) * 100, 2)
#
#     return (percentage_change, '')
#
# # Example usage:
# value_list = [{'number_value': 158371.0, 'scale': '', 'category': 'Wages and salaries', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 191459.0, 'scale': '', 'category': 'Wages and salaries', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 14802.0, 'scale': '', 'category': 'Social security', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 17214.0, 'scale': '', 'category': 'Social security', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 6937.0, 'scale': '', 'category': 'Pension expenses', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 8408.0, 'scale': '', 'category': 'Pension expenses', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 8215.0, 'scale': '', 'category': 'Share-based payment expenses', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 10538.0, 'scale': '', 'category': 'Share-based payment expenses', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 178.0, 'scale': '', 'category': 'Restructuring expenses', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 108.0, 'scale': '', 'category': 'Restructuring expenses', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 188503.0, 'scale': '', 'category': 'Total', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 227727.0, 'scale': '', 'category': 'Total', 'header1': '2019', 'header2': 'December 31,'}]
# print(run(value_list))
# ```
# code: def run(value_list):
#     total_expenses_2018 = sum(float(v['number_value'] * v['scale']) for v in value_list if v['category'] == 'Pension expenses' or v['category'] == 'Share-based payment expenses' for s in v.get('scale', '') if s.strip() != '0'))
#     total_expenses_2019 = sum(float(v['number_value'] * v['scale']) for v in value_list if v['category'] == 'Pension expenses' or v['category'] == 'Share-based payment expenses' for s in v.get('scale', '') if s.strip() != '0')
#     percentage_change = round(((total_expenses_2019 - total_expenses_2018) / total_expenses_2018) * 100, 2)
#
#     return (percentage_change, '')
#
# # Example usage:
# value_list = [{'number_value': 158371.0, 'scale': '', 'category': 'Wages and salaries', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 191459.0, 'scale': '', 'category': 'Wages and salaries', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 14802.0, 'scale': '', 'category': 'Social security', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 17214.0, 'scale': '', 'category': 'Social security', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 6937.0, 'scale': '', 'category': 'Pension expenses', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 8408.0, 'scale': '', 'category': 'Pension expenses', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 8215.0, 'scale': '', 'category': 'Share-based payment expenses', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 10538.0, 'scale': '', 'category': 'Share-based payment expenses', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 178.0, 'scale': '', 'category': 'Restructuring expenses', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 108.0, 'scale': '', 'category': 'Restructuring expenses', 'header1': '2019', 'header2': 'December 31,'},
#              {'number_value': 188503.0, 'scale': '', 'category': 'Total', 'header1': '2018', 'header2': 'December 31,'},
#              {'number_value': 227727.0, 'scale': '', 'category': 'Total', 'header1': '2019', 'header2': 'December 31,'}]
# print(run(value_list))
#
# [Error]unmatched ')' (<string>, line 2)
#  failure: [Error]unmatched ')' (<string>, line 2) good answer:  20.81
# ec696158-f93d-4608-903d-a6b9c4e7bfd5
# What is the increase / (decrease) in the telecommunication maintenance from 2018 to 2019?```python
# def run(value_list):
#     numbers = [item['number_value'] for item in value_list if 'number_value' in item]
#     values = [float(item) for item in numbers]
#
#     index1 = values.index(min(values)) - 1
#     index2 = values.index(max(values)) - 1
#
#     scale = ['million', 'billion', 'thousand', '', ''][-index2]
#     increase = (values[index1] / values[index2]) * 100 if index2 != len(values) else float('nan')
#
#     return round(increase, 2), scale
# ```
# code: def run(value_list):
#     numbers = [item['number_value'] for item in value_list if 'number_value' in item]
#     values = [float(item) for item in numbers]
#
#     index1 = values.index(min(values)) - 1
#     index2 = values.index(max(values)) - 1
#
#     scale = ['million', 'billion', 'thousand', '', ''][-index2]
#     increase = (values[index1] / values[index2]) * 100 if index2 != len(values) else float('nan')
#
#     return round(increase, 2), scale
#
# [Error]list index out of range
#  failure: [Error]list index out of range good answer:  -0.2
# 27911d6f-dfe5-487b-bc56-7e5cf16a32e0
# What is the average telecommunications installation?```python
# def run(value_list):
#     if len(value_list) == 0:
#         raise ValueError("Value list cannot be empty")
#
#     total = sum(value['number_value'] for value in value_list)
#     average = total / len(value_list)
#
#     return (format(average, '.2f'), "")
#
# # Example usage:
# value_list = [{'number_value': 86.8, 'scale': '', 'category': 'Telecommunication - Maintenance', 'header1': '2019', 'header2': 'Years Ended December 31,', 'header3': 'Years Ended December 31,'}, {'number_value': 87.0, 'scale': '', 'category': 'Telecommunication - Maintenance', 'header1': '2018', 'header2': 'Years Ended December 31,', 'header3': 'Years Ended December 31,'}, ...]
# average_telecommunications = run(value_list)
# print(average_telecommunications)  # Output: (87.0, '')
# ```
# code: def run(value_list):
#     if len(value_list) == 0:
#         raise ValueError("Value list cannot be empty")
#
#     total = sum(value['number_value'] for value in value_list)
#     average = total / len(value_list)
#
#     return (format(average, '.2f'), "")
#
# # Example usage:
# value_list = [{'number_value': 86.8, 'scale': '', 'category': 'Telecommunication - Maintenance', 'header1': '2019', 'header2': 'Years Ended December 31,', 'header3': 'Years Ended December 31,'}, {'number_value': 87.0, 'scale': '', 'category': 'Telecommunication - Maintenance', 'header1': '2018', 'header2': 'Years Ended December 31,', 'header3': 'Years Ended December 31,'}, ...]
# average_telecommunications = run(value_list)
# print(average_telecommunications)  # Output: (87.0, '')
#
# [Error]'ellipsis' object is not subscriptable
#  failure: [Error]'ellipsis' object is not subscriptable good answer:  37.35
# 3b8e873e-64d5-4af0-904f-7197dc632773
# What is the average Total Marine Services segment revenue?```python
# def run(value_list):
#     total_revenue = sum(item['number_value'] for item in value_list)
#     average_revenue = total_revenue / len(value_list)
#     return (round(average_revenue, 2), '')
# ```
#
# This function calculates the total revenue and then divides it by the number of items in the list to get the average. It returns a tuple with two elements: the first is the average as a float, and the second is an empty string for scale.
# code: def run(value_list):
#     total_revenue = sum(item['number_value'] for item in value_list)
#     average_revenue = total_revenue / len(value_list)
#     return (round(average_revenue, 2), '')
#
#  failure: 91.7 good answer:  183.4

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)
# Out:
# 0.0 0.0 0.05555555555555555

# %%
import re
res2 = []
for ans, pred, pred_scale, q,code, table,value_list,err in res:
    good = utils.eval_predicted_value(pred, ans['answer'])
    regex = re.compile("\\(\\d+,?\\d+", re.VERBOSE)    
    match = regex.search(str(table))
    
    match = match != None
    if pred == None or (type(pred) != int and  type(pred) != float):
        pred = 0
    res2.append( {'qid': q['uid'], 'question' : q['question'], 'derivation': q['derivation'], 'pred' : pred, 'pred_scale': pred_scale,  'answer': ans['answer'],  'scale':  ans['scale'],  'abs': 'abs(' in code, 'inv' : ans['answer'] == -1*pred,  'good': good, 'parenth': match})
res2 = pd.DataFrame(res2)
print(len(res2.query('good == True'))/len(res2))
# Out:
# 0.01284796573875803

# %%
res2['em'] = [i['em'] == 1.0 for i in list(metrics._details)]
res2.to_csv('res/Ollama_11_llama3.2_1b_code_values_v11_m1.csv')

# %%
type(2.0) == float
# Out:
# True

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [-1.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [4044.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [2349.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [16458.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [995.7],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12122000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [6.47],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [56.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [17.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [5309.6],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [244800.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-568.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [259.8],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-6841.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [63888.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.69999999999993],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [1303.1],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [8.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [-153391.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9307.75],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [201554.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
# ...
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [3695.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [4.52],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [-63.99],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1581.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [48784.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [1.32],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [36694.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [1.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [36.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
metrics._details[0]['pred'][0] == -94
# Out:
# True

# %%
scale_err =  [item for item in metrics._details if item['em'] != 1.0 and item['pred_scale'] != item['scale']]
only_scale_err =  [item for item in metrics._details if item['em'] != 1.0 and isinstance(item['pred'], list)  and  item['pred'][0] == item['answer']]
err =  [item for item in metrics._details if item['em'] != 1.0]
len (metrics._details), len(err), len(scale_err), len(only_scale_err)
# Out:
# (166, 56, 31, 20)

# %%
res = {}
for item in metrics._details:
  

    pred = item['pred']
    pred_scale = item['pred_scale']

    key = pred_scale +'|' + item['scale']
    if key not in res:
        res [key] = 1
    res[key]=res[key] +1


    if  item['em'] == 1.0:
        None
        #print("\033[92m Success: " + str(pred)+'\033[0m')
    else:           
 
        
        if isinstance(item['pred'], list) and  pred[0] == item['answer']:
           
            print("\033[93m", '|', " failure: ", '| ',str(pred[0]),  '| ', str(pred_scale), '| ', 'good answer: ', '| ', item['answer'], '| ', item['scale'], '\033[0m' )
        else:    
            None
            #print("\033[91m failure: " + str(pred),  str(pred_scale), 'good answer: ',item['answer'],item['scale'], '\033[0m' )
# Out:
#  |  failure:  |  62740.0 |   |  good answer:  |  62740 |  thousand
#  |  failure:  |  -19411.0 |   |  good answer:  |  -19411 |  thousand
#  |  failure:  |  12085176.0 |  thousand |  good answer:  |  12085176 |
#  |  failure:  |  28747.0 |  thousand |  good answer:  |  28747 |
#  |  failure:  |  113000.0 |  thousand |  good answer:  |  113000 |
#  |  failure:  |  111.4 |  million |  good answer:  |  111.4 |
#  |  failure:  |  107.15 |  million |  good answer:  |  107.15 |
#  |  failure:  |  -27603.0 |  thousand |  good answer:  |  -27603 |
#  |  failure:  |  3.0 |  million |  good answer:  |  3 |
#  |  failure:  |  -10029.67 |   |  good answer:  |  -10029.67 |  thousand
#  |  failure:  |  39.33 |  million |  good answer:  |  39.33 |
#  |  failure:  |  0.08 |  thousand |  good answer:  |  0.08 |  percent
#  |  failure:  |  16767.0 |   |  good answer:  |  16767 |  thousand
#  |  failure:  |  0.1 |   |  good answer:  |  0.1 |  million
#  |  failure:  |  54633874 |  thousand |  good answer:  |  54633874 |
#  |  failure:  |  0.18 |  thousand |  good answer:  |  0.18 |
#  |  failure:  |  0.97 |  thousand |  good answer:  |  0.97 |
#  |  failure:  |  3695.0 |  million |  good answer:  |  3695 |  thousand
#  |  failure:  |  39.3 |  million |  good answer:  |  39.3 |  percent
#  |  failure:  |  2.65 |  thousand |  good answer:  |  2.65 |
#  |  failure:  |  -0.2 |  million |  good answer:  |  -0.2 |  percent
#  |  failure:  |  1336.7 |  thousand |  good answer:  |  1336.7 |

# %%
res
# Out:
# {'million|million': 121,
#  'percent|percent': 177,
#  '|': 65,
#  'thousand|thousand': 82,
#  '|thousand': 11,
#  '|percent': 14,
#  'percent|': 3,
#  '|million': 5,
#  'thousand|': 11,
#  'million|percent': 5,
#  'million|': 9,
#  'thousand|percent': 2,
#  'billion|billion': 4,
#  'million|thousand': 2}

# %%
res
# Out:
# {'|thousand': 5,
#  'thousand|': 10,
#  'million|': 4,
#  'thousand|percent': 2,
#  '|million': 7,
#  'million|thousand': 2,
#  'million|percent': 3}

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [121.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [3680.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [3728.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [88.45],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12136.91],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [0.95],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [-56.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [-17.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': [2.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [4859.25],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [36.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-615.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [112.5],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-16105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [42592.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': [0.18],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [700.45],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [113.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [-9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9548.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [100777.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61,
#   'scale': 'percent',
#   'pred': [61.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 622908,
#   'scale': 'thousand',
#   'pred': [623111.0],
# ...
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 202845,
#   'scale': '',
#   'pred': [202845.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [11085.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [42.23],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [36.01],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1022.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [28101.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [-1.32],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [61584.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [0.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [100.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]
