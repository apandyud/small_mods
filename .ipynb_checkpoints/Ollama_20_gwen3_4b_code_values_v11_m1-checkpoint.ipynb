# %%
# code gen + values list

#### import tatqa_utils
import pandas as pd
import table_convert
import pyreadstat
#from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

import utils
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
import numpy as np
from progress.bar import Bar
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from langchain_community.chat_models import ChatOllama
from langchain.schema import HumanMessage
llm = ChatOllama(model="qwen3:4b")  # vagy bármely más elérhető Ollama modell

# %%
from langchain.globals import set_llm_cache
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
from langchain_community.cache import SQLiteCache

#llm = ChatOpenAI(temperature=0)
#llm = OpenAI(temperature=0) 
set_llm_cache(SQLiteCache(database_path=".langchain.ollama20.db"))

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
def get_question(qid):
    for i, item in devdf.iterrows():
        for q in item['questions']:        
            if q['uid'] == qid:
                #table = item['table']['table']
                return (item['table'], q)
    return (None, None)

# %%
def gen_code3(llm, messages, question, value_list): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"value_list": value_list, "question":question})
    print("R: ", response)
    idx = response.rfind("</think") + len("</think")
    code =  response[idx:]
    #code =  response.replace('```python','').replace('```','')
    print("code: ", code)
    
    return (prompt.format(value_list = value_list, question = question), code)

def exec_code(code, value_list):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({value_list})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

def gen_code_table(llm, messages, question, table): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"table": table, "question":question})
    code =  response.replace('```python','').replace('```','')
    
    return (prompt.format(table = table, question = question), code)

def exec_code_table(code, table):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({table})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

# %%
def get_answer(llm, messages, table, q):
    values = table_convert.convert_multitable(table)    
    p, code = gen_code3(llm, messages, q, values)    
    print(code)
    (v, s) = exec_code(code, values)
    return  (v, s, code)

# %%
import prompt_versions
items = [i for idx, i in devdf.iterrows()]
item = items[1]
table = item['table']['table']
q = item.questions[4]
question = q['question']
#print(table, question)
r = get_answer(llm, prompt_versions.prompt_versions['V11'], table, question)
print(r[0], r[1], r[2])
# Out:
# >
#
# def run(value_list):
#     # Find 2019 Appliances value
#     ap_2019 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2019')
#     # Find 2018 Appliances value
#     ap_2018 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2018')
#     # Calculate change
#     change = ap_2019 - ap_2018
#     # Return formatted result
#     return (round(change, 2), 'million')
# [Error]invalid syntax (<string>, line 1)
# [Error]invalid syntax (<string>, line 1)  >
#
# def run(value_list):
#     # Find 2019 Appliances value
#     ap_2019 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2019')
#     # Find 2018 Appliances value
#     ap_2018 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2018')
#     # Calculate change
#     change = ap_2019 - ap_2018
#     # Return formatted result
#     return (round(change, 2), 'million')

# %%
from tqdm.notebook import tqdm as log_progress
import prompt_versions

devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')
cnt = 0
res = []
for i, item in log_progress(devdf.iterrows()):
    try:
        #if cnt == 36:
        #    break;
        #print(item['table']['uid'])
        table = item['table']['table']
        value_list = table_convert.convert_multitable(table)    
        text = '\n'.join( [p['text'] for p in item['paragraphs']])
        for q in item['questions']:        
            if q['answer_type'] == 'arithmetic' and 'table' == q['answer_from']:   
                cnt = cnt + 1
                print(q['uid'])
                _table, _q =  get_question(q['uid'])
                
                table = _table['table']
                
                #[print(r) for r in table]
                
                q = _q['question']
                print(q, end='')
                
                
                r = []
                #for i in [0,1,2]:        
                #   r.append(get_answer(llm, messages, table, q))
                
                #if r[0][0] == r[1][0]:
                #    (v, s) = r[0]
                #elif r[1][0] == r[2][0]:
                #    (v, s) = r[1]
                #elif r[0][0] == r[2][0]:
                #    (v, s) = r[0]
                #else:
                #    (v, s) = (None, None)
                    
                #(v, s, code) = get_answer(llm, messages, table, q)    
                (pred_value, pred_scale, code) = get_answer(llm, prompt_versions.prompt_versions['V11'], table, q)    
                
                if 'in millions' in text.lower() and pred_scale == '':
                    pred_scale = 'million'
                    
                if  utils.eval_predicted_value(pred_value, _q['answer']):
                    print("\033[92m Success: " + str(pred_value)+'\033[0m')
                else:    
                    print("\033[91m failure: " + str(pred_value), 'good answer: ', _q['answer'],'\033[0m' )
                
                if isinstance(pred_value, tuple) and len(pred_value) == 2:
                    print('$$$$')
                    (pred_value, pred_scale) = pred_value
                if pred_scale == "%" or pred_scale == "percentage"  :
                    pred_scale = 'percent'
                if pred_scale not in ["", 'thousand', 'million', 'billion', 'percent']:
                    print('Invalid ', pred_scale)
                    pred_scale = ""    
                #if item['table']['uid'] in res_scale and pred_scale != 'percent':
                #    pred_scale = res_scale[item['table']['uid']]
                err=""
                if isinstance(pred_value, str):
                    #print("string")
                    if  pred_value.startswith('[Error]'):
                        err = pred_value
                        (pred_value, pred_scale) = ("", "")
                                                                              
                res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, pred_value, pred_scale, _q, code, table,value_list, err))
    except Exception as e:
        s = '[Outer Exception]'+ str(e)
        print(s)
        res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, "", "", _q, "", table,"", s))
# Out:
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018? I need to find the Appliances values for 2019 and 2018, then calculate the difference. Let me check the data again. The Appliances category is under Communications Solutions. For 2019, the value is 680.0 million. For 2018, it's 774.0 million. The change is 680 - 774 = -94.0 million. So the answer is -94.0, scale is million. I need to format it as a tuple with two decimal places. Wait, the scale is million, so the number is -94.00. But the function should return the number and scale. Let me make sure the function is correctly structured.
# </think>
#
# def run(value_list):
#     # Find 2019 Appliances value
#     ap_2019 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2019')
#     # Find 2018 Appliances value
#     ap_2018 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2018')
#     # Calculate change
#     change = ap_2019 - ap_2018
#     # Return formatted result
#     return (round(change, 2), 'million')
#  I need to find the Appliances values for 2019 and 2018, then calculate the difference. Let me check the data again. The Appliances category is under Communications Solutions. For 2019, the value is 680.0 million. For 2018, it's 774.0 million. The change is 680 - 774 = -94.0 million. So the answer is -94.0, scale is million. I need to format it as a tuple with two decimal places. Wait, the scale is million, so the number is -94.00. But the function should return the number and scale. Let me make sure the function is correctly structured.
# </think>
#
# def run(value_list):
#     # Find 2019 Appliances value
#     ap_2019 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2019')
#     # Find 2018 Appliances value
#     ap_2018 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2018')
#     # Calculate change
#     change = ap_2019 - ap_2018
#     # Return formatted result
#     return (round(change, 2), 'million')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  -94
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018? I need to find the 2019 and 2018 values for Appliances. Looking at the list, Appliances are under Communications Solutions. The 2019 value is 680.0 million, and 2018 is 774.0 million. The percentage change is ((680 - 774)/774)*100, which is -12.17%. The scale is million. So the function should return (-12.17, 'million').
# </think>
#
# def run(value_list):
#     # Find 2019 Appliances value
#     ap_2019 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2019')
#     # Find 2018 Appliances value
#     ap_2018 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2018')
#     # Calculate percentage change
#     change = ((ap_2019 - ap_2018) / ap_2018) * 100
#     return (round(change, 2), 'million')
#  I need to find the 2019 and 2018 values for Appliances. Looking at the list, Appliances are under Communications Solutions. The 2019 value is 680.0 million, and 2018 is 774.0 million. The percentage change is ((680 - 774)/774)*100, which is -12.17%. The scale is million. So the function should return (-12.17, 'million').
# </think>
#
# def run(value_list):
#     # Find 2019 Appliances value
#     ap_2019 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2019')
#     # Find 2018 Appliances value
#     ap_2018 = next(v['number_value'] for v in value_list if v['category'] == 'Appliances' and v['header3'] == '2018')
#     # Calculate percentage change
#     change = ((ap_2019 - ap_2018) / ap_2018) * 100
#     return (round(change, 2), 'million')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  -12.14
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019? I need to find the discount rates for domestic and international for 2019. The domestic rate is 4.0% and the international is 1.9%. The difference is 4.0 - 1.9 = 2.1. So the answer is (2.1, '%').
# </think>
#
# (2.1, '%')
#  I need to find the discount rates for domestic and international for 2019. The domestic rate is 4.0% and the international is 1.9%. The difference is 4.0 - 1.9 = 2.1. So the answer is (2.1, '%').
# </think>
#
# (2.1, '%')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  2.1
# 4dc8be43-d8d9-4b08-9ffd-9c19012361ce
# What is the year on year percentage change in domestic discount rate between 2018 and 2019? First, I need to find the domestic discount rates for 2018 and 2019. Looking at the value list, the 2018 domestic discount rate is 3.75%, and the 2019 domestic discount rate is 4.0%. The year-on-year percentage change is calculated by ((new - old)/old) * 100. So (4.0 - 3.75)/3.75 * 100 = 6.666...%, which rounds to 6.67%. The scale is '%'. So the function should return (6.67, '%').
# </think>
#
# (6.67, '%')
#  First, I need to find the domestic discount rates for 2018 and 2019. Looking at the value list, the 2018 domestic discount rate is 3.75%, and the 2019 domestic discount rate is 4.0%. The year-on-year percentage change is calculated by ((new - old)/old) * 100. So (4.0 - 3.75)/3.75 * 100 = 6.666...%, which rounds to 6.67%. The scale is '%'. So the function should return (6.67, '%').
# </think>
#
# (6.67, '%')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  6.67
# 6c44a1a8-0785-43a0-90ab-7e21df2c57d9
# What is the year on year percentage change in international expected return on plan assets between 2018 and 2019? the function takes the value list as input. We need to find the international expected return on plan assets for 2018 and 2019. The 2018 value is 3.7%, and the 2019 value is 3.4%. The year-on-year change is (3.4 - 3.7)/3.7 * 100, which is -8.108...%, rounded to two decimal places as -8.11%. But wait, the question is asking for the percentage change, so the answer should be -8.11%.
# </think>
#
# ( -8.11, '%' )
#  the function takes the value list as input. We need to find the international expected return on plan assets for 2018 and 2019. The 2018 value is 3.7%, and the 2019 value is 3.4%. The year-on-year change is (3.4 - 3.7)/3.7 * 100, which is -8.108...%, rounded to two decimal places as -8.11%. But wait, the question is asking for the percentage change, so the answer should be -8.11%.
# </think>
#
# ( -8.11, '%' )
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  -8.11
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes?
#
# First, I need to filter the entries for 'Defined contribution schemes' and 2019. Then, calculate the average of those values. The scale is 'million' as per the data. The result should be a float with two decimal places.
#
# So the function would look like this:
# </think>
#
# def run(value_list):
#     # Filter for 'Defined contribution schemes' and 2019
#     contrib_2019 = [item['number_value'] for item in value_list if item['category'] == 'Defined contribution schemes' and item['header1'] == '2019 € million']
#     avg = sum(contrib_2019) / len(contrib_2019)
#     return (round(avg, 2), 'million')
#
#
# First, I need to filter the entries for 'Defined contribution schemes' and 2019. Then, calculate the average of those values. The scale is 'million' as per the data. The result should be a float with two decimal places.
#
# So the function would look like this:
# </think>
#
# def run(value_list):
#     # Filter for 'Defined contribution schemes' and 2019
#     contrib_2019 = [item['number_value'] for item in value_list if item['category'] == 'Defined contribution schemes' and item['header1'] == '2019 € million']
#     avg = sum(contrib_2019) / len(contrib_2019)
#     return (round(avg, 2), 'million')
# [Error]invalid syntax (<string>, line 3)
#  failure: [Error]invalid syntax (<string>, line 3) good answer:  172
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes? I need to find the 2019 average for defined benefit schemes. Looking at the value list, the defined benefit schemes for 2019 is 57 million. Since there's only one value, the average is 57.00 million. So the function should return (57.00, 'million').
# </think>
#
# (57.0, 'million')
#  I need to find the 2019 average for defined benefit schemes. Looking at the value list, the defined benefit schemes for 2019 is 57 million. Since there's only one value, the average is 57.00 million. So the function should return (57.00, 'million').
# </think>
#
# (57.0, 'million')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  50.5
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes? The function will take the value_list as input. First, I need to filter the entries for 2019. Then, for each category (defined contribution schemes and defined benefit schemes), I'll calculate the average of their values. Finally, subtract the average of defined benefit schemes from the average of defined contribution schemes. The scale is 'million' as per the data. The result should be a float with two decimal places. Let me write that code.
# </think>
#
# def run(value_list):
#     # Filter 2019 entries
#     twenty19 = [v for v in value_list if v['header1'] == '2019 € million']
#     # Calculate average for defined contribution schemes
#     contrib_avg = sum(v['number_value'] for v in twenty19 if v['category'] == 'Defined contribution schemes') / 3
#     # Calculate average for defined benefit schemes
#     benefit_avg = sum(v['number_value'] for v in twenty19 if v['category'] == 'Defined benefit schemes') / 3
#     # Return difference with million scale
#     return (round(contrib_avg - benefit_avg, 2), 'million')
#  The function will take the value_list as input. First, I need to filter the entries for 2019. Then, for each category (defined contribution schemes and defined benefit schemes), I'll calculate the average of their values. Finally, subtract the average of defined benefit schemes from the average of defined contribution schemes. The scale is 'million' as per the data. The result should be a float with two decimal places. Let me write that code.
# </think>
#
# def run(value_list):
#     # Filter 2019 entries
#     twenty19 = [v for v in value_list if v['header1'] == '2019 € million']
#     # Calculate average for defined contribution schemes
#     contrib_avg = sum(v['number_value'] for v in twenty19 if v['category'] == 'Defined contribution schemes') / 3
#     # Calculate average for defined benefit schemes
#     benefit_avg = sum(v['number_value'] for v in twenty19 if v['category'] == 'Defined benefit schemes') / 3
#     # Return difference with million scale
#     return (round(contrib_avg - benefit_avg, 2), 'million')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  121.5
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019? I need to calculate the percentage change in the operating loss carryforward from 2018 to 2019. First, I'll find the values for 2018 and 2019. The operating loss carryforward for 2019 is 73260.0 thousand, and for 2018 it's 57768.0 thousand. The formula for percentage change is ((new - old)/old) * 100. So (73260 - 57768)/57768 * 100. Let me calculate that. The difference is 15492. Divided by 57768 gives approximately 0.2685. Multiply by 100 gives 26.85%. The scale is percent. So the function should return (26.85, 'percent').
# </think>
#
# def run(value_list):
#     # Extract 2018 and 2019 operating loss carryforward values
#     # Find the 2018 value
#     for item in value_list:
#         if item['category'] == 'Operating loss carryforward' and item['header2'] == '2 0 1 8':
#             val_2018 = item['number_value']
#             break
#     # Find the 2019 value
#     for item in value_list:
#         if item['category'] == 'Operating loss carryforward' and item['header2'] == '2019':
#             val_2019 = item['number_value']
#             break
#     # Calculate percentage change
#     change = ((val_2019 - val_2018) / val_2018) * 100
#     return (round(change, 2), 'percent')
#  I need to calculate the percentage change in the operating loss carryforward from 2018 to 2019. First, I'll find the values for 2018 and 2019. The operating loss carryforward for 2019 is 73260.0 thousand, and for 2018 it's 57768.0 thousand. The formula for percentage change is ((new - old)/old) * 100. So (73260 - 57768)/57768 * 100. Let me calculate that. The difference is 15492. Divided by 57768 gives approximately 0.2685. Multiply by 100 gives 26.85%. The scale is percent. So the function should return (26.85, 'percent').
# </think>
#
# def run(value_list):
#     # Extract 2018 and 2019 operating loss carryforward values
#     # Find the 2018 value
#     for item in value_list:
#         if item['category'] == 'Operating loss carryforward' and item['header2'] == '2 0 1 8':
#             val_2018 = item['number_value']
#             break
#     # Find the 2019 value
#     for item in value_list:
#         if item['category'] == 'Operating loss carryforward' and item['header2'] == '2019':
#             val_2019 = item['number_value']
#             break
#     # Calculate percentage change
#     change = ((val_2019 - val_2018) / val_2018) * 100
#     return (round(change, 2), 'percent')
# [Error]unexpected indent (<string>, line 1)
#  failure: [Error]unexpected indent (<string>, line 1) good answer:  26.82
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019?
#
# First, I need to find the net deferred tax asset values for 2018 and 2019. Looking at the value list, the entries with category 'Net deferred tax asset' have the number_values for those years. For 2019, the number_value is 795.0 (thousand), and for 2018, it's 772.0 (thousand).
#
# To calculate the percentage change, the formula is ((new - old)/old)*100. So (795 - 772)/772 * 100. That equals 23/772 * 100. Let me compute that. 23 divided by 772 is approximately 0.0298, multiplied by 100 gives 2.98%.
#
# The scale for both is 'thousand', so the answer is 2.98% (since the scale is thousand, but the percentage is unitless). The function should return (2.98, 'percent').
# </think>
#
# (2.98, 'percent')
#
#
# First, I need to find the net deferred tax asset values for 2018 and 2019. Looking at the value list, the entries with category 'Net deferred tax asset' have the number_values for those years. For 2019, the number_value is 795.0 (thousand), and for 2018, it's 772.0 (thousand).
#
# To calculate the percentage change, the formula is ((new - old)/old)*100. So (795 - 772)/772 * 100. That equals 23/772 * 100. Let me compute that. 23 divided by 772 is approximately 0.0298, multiplied by 100 gives 2.98%.
#
# The scale for both is 'thousand', so the answer is 2.98% (since the scale is thousand, but the percentage is unitless). The function should return (2.98, 'percent').
# </think>
#
# (2.98, 'percent')
# [Error]invalid syntax (<string>, line 3)
#  failure: [Error]invalid syntax (<string>, line 3) good answer:  2.98
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 43
#      29 r = []
#      30 #for i in [0,1,2]:
#      31 #   r.append(get_answer(llm, messages, table, q))
#      32
#    (...)
#      41
#      42 #(v, s, code) = get_answer(llm, messages, table, q)
# ---> 43 (pred_value, pred_scale, code) = get_answer(llm, prompt_versions.prompt_versions['V11'], table, q)
#      45 if 'in millions' in text.lower() and pred_scale == '':
#      46     pred_scale = 'million'
#
# Cell In[31], line 3, in get_answer(llm, messages, table, q)
#       1 def get_answer(llm, messages, table, q):
#       2     values = table_convert.convert_multitable(table)
# ----> 3     p, code = gen_code3(llm, messages, q, values)
#       4     print(code)
#       5     (v, s) = exec_code(code, values)
#
# Cell In[30], line 9, in gen_code3(llm, messages, question, value_list)
#       5 output_parser = StrOutputParser()
#       7 chain = prompt | llm | output_parser
# ----> 9 response = chain.invoke({"value_list": value_list, "question":question})
#      10 print(response)
#      11 code =  response.replace('```python','').replace('```','')
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_core/runnables/base.py:2879, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2877             input = context.run(step.invoke, input, config, **kwargs)
#    2878         else:
# -> 2879             input = context.run(step.invoke, input, config)
#    2880 # finish the root run
#    2881 except BaseException as e:
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:277, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     266 def invoke(
#     267     self,
#     268     input: LanguageModelInput,
#    (...)
#     272     **kwargs: Any,
#     273 ) -> BaseMessage:
#     274     config = ensure_config(config)
#     275     return cast(
#     276         ChatGeneration,
# --> 277         self.generate_prompt(
#     278             [self._convert_input(input)],
#     279             stop=stop,
#     280             callbacks=config.get("callbacks"),
#     281             tags=config.get("tags"),
#     282             metadata=config.get("metadata"),
#     283             run_name=config.get("run_name"),
#     284             run_id=config.pop("run_id", None),
#     285             **kwargs,
#     286         ).generations[0][0],
#     287     ).message
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:777, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     769 def generate_prompt(
#     770     self,
#     771     prompts: List[PromptValue],
#    (...)
#     774     **kwargs: Any,
#     775 ) -> LLMResult:
#     776     prompt_messages = [p.to_messages() for p in prompts]
# --> 777     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:634, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     632         if run_managers:
#     633             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 634         raise e
#     635 flattened_outputs = [
#     636     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     637     for res in results
#     638 ]
#     639 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:624, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     621 for i, m in enumerate(messages):
#     622     try:
#     623         results.append(
# --> 624             self._generate_with_cache(
#     625                 m,
#     626                 stop=stop,
#     627                 run_manager=run_managers[i] if run_managers else None,
#     628                 **kwargs,
#     629             )
#     630         )
#     631     except BaseException as e:
#     632         if run_managers:
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:846, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     844 else:
#     845     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 846         result = self._generate(
#     847             messages, stop=stop, run_manager=run_manager, **kwargs
#     848         )
#     849     else:
#     850         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_community/chat_models/ollama.py:286, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     262 def _generate(
#     263     self,
#     264     messages: List[BaseMessage],
#    (...)
#     267     **kwargs: Any,
#     268 ) -> ChatResult:
#     269     """Call out to Ollama's generate endpoint.
#     270
#     271     Args:
#    (...)
#     283             ])
#     284     """
# --> 286     final_chunk = self._chat_stream_with_aggregation(
#     287         messages,
#     288         stop=stop,
#     289         run_manager=run_manager,
#     290         verbose=self.verbose,
#     291         **kwargs,
#     292     )
#     293     chat_generation = ChatGeneration(
#     294         message=AIMessage(content=final_chunk.text),
#     295         generation_info=final_chunk.generation_info,
#     296     )
#     297     return ChatResult(generations=[chat_generation])
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_community/chat_models/ollama.py:217, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     208 def _chat_stream_with_aggregation(
#     209     self,
#     210     messages: List[BaseMessage],
#    (...)
#     214     **kwargs: Any,
#     215 ) -> ChatGenerationChunk:
#     216     final_chunk: Optional[ChatGenerationChunk] = None
# --> 217     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     218         if stream_resp:
#     219             chunk = _chat_stream_response_to_chat_generation_chunk(stream_resp)
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/langchain_community/chat_models/ollama.py:189, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     179 def _create_chat_stream(
#     180     self,
#     181     messages: List[BaseMessage],
#     182     stop: Optional[List[str]] = None,
#     183     **kwargs: Any,
#     184 ) -> Iterator[str]:
#     185     payload = {
#     186         "model": self.model,
#     187         "messages": self._convert_messages_to_ollama_messages(messages),
#     188     }
# --> 189     yield from self._create_stream(
#     190         payload=payload, stop=stop, api_url=f"{self.base_url}/api/chat", **kwargs
#     191     )
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/requests/models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/requests/utils.py:572, in stream_decode_response_unicode(iterator, r)
#     569     return
#     571 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 572 for chunk in iterator:
#     573     rv = decoder.decode(chunk)
#     574     if rv:
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/urllib3/response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/urllib3/response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File ~/environemnts/tabular/lib/python3.8/site-packages/urllib3/response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)
# Out:
# 0.3702213279678068 0.3702213279678068 0.5714285714285714

# %%
import re
res2 = []
for ans, pred, pred_scale, q,code, table,value_list,err in res:
    good = utils.eval_predicted_value(pred, ans['answer'])
    regex = re.compile("\\(\\d+,?\\d+", re.VERBOSE)    
    match = regex.search(str(table))
    
    match = match != None
    if pred == None:
        pred = 0
    res2.append( {'qid': q['uid'], 'question' : q['question'], 'derivation': q['derivation'], 'pred' : pred, 'pred_scale': pred_scale,  'answer': ans['answer'],  'scale':  ans['scale'],  'abs': 'abs(' in code, 'inv' : ans['answer'] == -1*pred,  'good': good, 'parenth': match})
res2 = pd.DataFrame(res2)
print(len(res2.query('good == True'))/len(res2))
# Out:
# 0.5633802816901409

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [-1.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [4044.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [2349.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [16458.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [995.7],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12122000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [6.47],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [56.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [17.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [5309.6],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [244800.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-568.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [259.8],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-6841.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [63888.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.69999999999993],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [1303.1],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [8.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [-153391.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9307.75],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [201554.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
# ...
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [3695.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [4.52],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [-63.99],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1581.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [48784.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [1.32],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [36694.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [1.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [36.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
metrics._details[0]['pred'][0] == -94
# Out:
# True

# %%
scale_err =  [item for item in metrics._details if item['em'] != 1.0 and item['pred_scale'] != item['scale']]
only_scale_err =  [item for item in metrics._details if item['em'] != 1.0 and isinstance(item['pred'], list)  and  item['pred'][0] == item['answer']]
err =  [item for item in metrics._details if item['em'] != 1.0]
len (metrics._details), len(err), len(scale_err), len(only_scale_err)
# Out:
# (166, 56, 31, 20)

# %%
res = {}
for item in metrics._details:
  

    pred = item['pred']
    pred_scale = item['pred_scale']

    key = pred_scale +'|' + item['scale']
    if key not in res:
        res [key] = 1
    res[key]=res[key] +1


    if  item['em'] == 1.0:
        None
        #print("\033[92m Success: " + str(pred)+'\033[0m')
    else:           
 
        
        if isinstance(item['pred'], list) and  pred[0] == item['answer']:
           
            print("\033[93m", '|', " failure: ", '| ',str(pred[0]),  '| ', str(pred_scale), '| ', 'good answer: ', '| ', item['answer'], '| ', item['scale'], '\033[0m' )
        else:    
            None
            #print("\033[91m failure: " + str(pred),  str(pred_scale), 'good answer: ',item['answer'],item['scale'], '\033[0m' )
# Out:
#  |  failure:  |  62740.0 |   |  good answer:  |  62740 |  thousand
#  |  failure:  |  -19411.0 |   |  good answer:  |  -19411 |  thousand
#  |  failure:  |  12085176.0 |  thousand |  good answer:  |  12085176 |
#  |  failure:  |  28747.0 |  thousand |  good answer:  |  28747 |
#  |  failure:  |  113000.0 |  thousand |  good answer:  |  113000 |
#  |  failure:  |  111.4 |  million |  good answer:  |  111.4 |
#  |  failure:  |  107.15 |  million |  good answer:  |  107.15 |
#  |  failure:  |  -27603.0 |  thousand |  good answer:  |  -27603 |
#  |  failure:  |  3.0 |  million |  good answer:  |  3 |
#  |  failure:  |  -10029.67 |   |  good answer:  |  -10029.67 |  thousand
#  |  failure:  |  39.33 |  million |  good answer:  |  39.33 |
#  |  failure:  |  0.08 |  thousand |  good answer:  |  0.08 |  percent
#  |  failure:  |  16767.0 |   |  good answer:  |  16767 |  thousand
#  |  failure:  |  0.1 |   |  good answer:  |  0.1 |  million
#  |  failure:  |  54633874 |  thousand |  good answer:  |  54633874 |
#  |  failure:  |  0.18 |  thousand |  good answer:  |  0.18 |
#  |  failure:  |  0.97 |  thousand |  good answer:  |  0.97 |
#  |  failure:  |  3695.0 |  million |  good answer:  |  3695 |  thousand
#  |  failure:  |  39.3 |  million |  good answer:  |  39.3 |  percent
#  |  failure:  |  2.65 |  thousand |  good answer:  |  2.65 |
#  |  failure:  |  -0.2 |  million |  good answer:  |  -0.2 |  percent
#  |  failure:  |  1336.7 |  thousand |  good answer:  |  1336.7 |

# %%
res
# Out:
# {'million|million': 121,
#  'percent|percent': 177,
#  '|': 65,
#  'thousand|thousand': 82,
#  '|thousand': 11,
#  '|percent': 14,
#  'percent|': 3,
#  '|million': 5,
#  'thousand|': 11,
#  'million|percent': 5,
#  'million|': 9,
#  'thousand|percent': 2,
#  'billion|billion': 4,
#  'million|thousand': 2}

# %%
res
# Out:
# {'|thousand': 5,
#  'thousand|': 10,
#  'million|': 4,
#  'thousand|percent': 2,
#  '|million': 7,
#  'million|thousand': 2,
#  'million|percent': 3}

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [121.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [3680.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [3728.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [88.45],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12136.91],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [0.95],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [-56.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [-17.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': [2.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [4859.25],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [36.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-615.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [112.5],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-16105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [42592.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': [0.18],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [700.45],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [113.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [-9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9548.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [100777.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61,
#   'scale': 'percent',
#   'pred': [61.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 622908,
#   'scale': 'thousand',
#   'pred': [623111.0],
# ...
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 202845,
#   'scale': '',
#   'pred': [202845.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [11085.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [42.23],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [36.01],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1022.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [28101.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [-1.32],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [61584.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [0.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [100.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]
