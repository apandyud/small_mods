# %%
import cga_utils
import prompt_versions
# %load_ext autoreload
# %autoreload 2

# %%
from langchain.globals import set_llm_cache
from langchain_community.cache import SQLiteCache
set_llm_cache(SQLiteCache(database_path=".langchain.ollama41.db"))

# %%
from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model="phi3:3.8b", temperature = 0.0, top_p = 1, repeat_penalty=1, presence_penalty=0, frequency_penalty=0)  # vagy bármely más elérhető Ollama modell

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V18']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 



#problematic_qids = list(pd.read_csv('res/e37.csv').query('error_code == "selection_error" and calc_pattern == "(#+#)/#"')['qid'])
#df = pd.read_csv('res/e38_19.csv')
#problematic_qids = list(df[df["question"].str.contains("percentage change")]['qid'])

res = cga_utils.execute_datset_predictions(llm, messages)
#res = []
#for i in range(3):
#    set_llm_cache(SQLiteCache(database_path=".langchain.ollama38_run" + str(i) + ".db"))
#    res.append(cga_utils.execute_datset_predictions(llm, messages))
# Out:
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018? Success: -94.0
# << 680-774 || [-94.0] || [680.0, 774.0] || False >>
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018?[Outer Exception]too many values to unpack (expected 2)
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019?[Outer Exception]too many values to unpack (expected 2)
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes? failure: 166.0 good answer:  172
# << (166+178)/2 || [166.0, 1, 166.0] || [166.0, 178.0] || False >>
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes? failure: 57.0 good answer:  50.5
# << (57+44)/2 || [57.0, 1, 57.0] || [57.0, 44.0] || False >>
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?[Outer Exception]too many values to unpack (expected 2)
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019?[Error]
# [Error]
#  failure: [Error] good answer:  26.82
# << (73,260-57,768)/57,768 || [] || [73260.0, 57768.0, 57768.0] || False >>
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019?[Error]
# [Error]
#  failure: [Error] good answer:  2.98
# << (795-772)/772 || [] || [795.0, 772.0, 772.0] || False >>
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019?[Outer Exception]too many values to unpack (expected 2)
# a4f782f1-de3b-47a3-87af-1cb33c112b39
# What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?[Error]
# [Error]
#  failure: [Error] good answer:  14.07
# << (592-519)/519 || [] || [592.0, 519.0, 519.0] || False >>
# dc5e217a-a7b3-4fc9-ac0f-13d328f26b20
# What is the 2019 average free cash flow? failure: 4411.0 good answer:  4227.5
# << (4,411+4,044)/2 || [4411.0] || [4411.0, 4044.0] || False >>
# 7cd3aedf-1291-4fea-bc9d-a25c65727b7b
# What is the 2018 average free cash flow? failure: 4044.0 good answer:  3680
# << (4,044+3,316)/2 || [4044.0] || [4044.0, 3316.0] || False >>
# 22e20f25-669a-46b9-8779-2768ba391955
# What is the change between 2018 and 2019 average free cash flow?[Error]unsupported operand type(s) for -: 'tuple' and 'tuple'
# [Error]unsupported operand type(s) for -: 'tuple' and 'tuple'
#  failure: [Error]unsupported operand type(s) for -: 'tuple' and 'tuple' good answer:  547.5
# << [(4,411+4,044)/2] -[(4,044+3,316)/2] || [] || [4411.0, 4044.0, 4044.0, 3316.0] || False >>
# a983501d-2eec-486d-9661-e520c7c8af5e
# What was the average difference between EBITDA and underlying EBITDA for both FYs?[Outer Exception]too many values to unpack (expected 2)
# 91812b92-5e94-414f-a447-4622aa3c2d10
# What was the average dividend yield for the 3 years from 2017 to 2019?[Outer Exception]too many values to unpack (expected 2)
# 6100c476-160a-4f1e-bfc1-a16f4cc18b52
# What was the increase / (decrease) in the cost from 2018 to 2019?[Outer Exception]too many values to unpack (expected 2)
# 65ec782c-691e-45df-b541-caecb85154ff
# What was the change in Capital redemption reserve in 2019 from 2018?[Error]unsupported operand type(s) for -: 'tuple' and 'tuple'
# [Error]unsupported operand type(s) for -: 'tuple' and 'tuple'
#  failure: [Error]unsupported operand type(s) for -: 'tuple' and 'tuple' good answer:  0.2
# << 0.7-0.5 || [] || [0.7, 0.5] || False >>
# 94916f79-4b6d-487f-8fa2-39f81a085760
# What was the percentage change in Capital redemption reserve in 2019 from 2018?[Outer Exception]too many values to unpack (expected 2)
# bbe335ff-414f-48b3-8126-5a2c7c505de3
# How much was the average operating income from 2015 to 2019? Success: 13237.4
# <<  (13,535+13,264+12,913+12,604+13,871) / 5  || [13237.4] || [13535.0, 13264.0, 12913.0, 12604.0, 13871.0] || False >>
# ef274d2b-fbd6-4e9f-95f9-79b37827d91c
# What was the total expenses for Oracle in 2018?[Outer Exception]local variable 'code' referenced before assignment
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492
# What were the total Assets as reported?[Outer Exception]too many values to unpack (expected 2)
# 58adf6c4-41ae-4f3f-84cb-cf3469a80ce4
# What was the percentage change in Total Other operating expenses between 2018 and 2019?[Outer Exception]too many values to unpack (expected 2)
# 79f06004-f4fc-4e82-a9fe-3c389a2f81b6
# What was the change in the statutory federal income tax rate from 2018 to 2019? Success: 0.0
# << 21.0% - 21.0% || [21.0, 21.0, 0.0] || [21.0, 21.0] || True >>
# a360cee9-ce60-4f29-988d-8c6c627bb51f
# What was the average State and local income tax rate, net of federal tax benefits between 2017-2019?[Outer Exception]too many values to unpack (expected 2)
# 6cc73a99-0323-40d5-9d92-b285579b3482
# What was the percentage change in gross profit between 2018 and 2019?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       2 messages = prompt_versions.prompt_versions['V18']
#       3 #messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#       4 #messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" )
#       5
#    (...)
#       9 #df = pd.read_csv('res/e38_19.csv')
#      10 #problematic_qids = list(df[df["question"].str.contains("percentage change")]['qid'])
# ---> 12 res = cga_utils.execute_datset_predictions(llm, messages)
#      13 #res = []
#      14 #for i in range(3):
#      15 #    set_llm_cache(SQLiteCache(database_path=".langchain.ollama38_run" + str(i) + ".db"))
#      16 #    res.append(cga_utils.execute_datset_predictions(llm, messages))
#
# File ~/Tabular/tab_small/cga_utils.py:200, in execute_datset_predictions(llm, messages, selected_qids, trace)
#     196 print(q, end='')
#     198 r = []
# --> 200 (pred_value, pred_scale, trace) = get_answer_with_trace(llm, messages, table,_q)
#     204 if 'in millions' in text.lower() and pred_scale == '':
#     205     pred_scale = 'million'
#
# File ~/Tabular/tab_small/cga_utils.py:162, in get_answer_with_trace(llm, messages, table, q)
#     160 q_text = q['question']
#     161 #print( q_text, q['derivation'], q['answer'] )
# --> 162 (v, s, trace) = get_answer(llm, messages, table, q_text)
#     163 available_values = [i['number_value'] for i in trace['value_list'] ]
#     164 #print(trace['captured_locals'])
#
# File ~/Tabular/tab_small/cga_utils.py:153, in get_answer(llm, messages, table, q_text)
#     151 values = table_convert.convert_multitable(table)
#     152 #print(values)
# --> 153 p, code = gen_code(llm, messages, q_text, values)
#     154 r = exec_code(code, values)
#     155 #print(code)
#
# File ~/Tabular/tab_small/cga_utils.py:117, in gen_code(llm, messages, question, value_list)
#     113 output_parser = StrOutputParser()
#     115 chain = prompt | llm | output_parser
# --> 117 response = chain.invoke({"value_list": value_list, "question":question})
#     119 #print("R: ", response + "|")
#     121 if "```python" in response:
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_core/runnables/base.py:2879, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2877             input = context.run(step.invoke, input, config, **kwargs)
#    2878         else:
# -> 2879             input = context.run(step.invoke, input, config)
#    2880 # finish the root run
#    2881 except BaseException as e:
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:277, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     266 def invoke(
#     267     self,
#     268     input: LanguageModelInput,
#    (...)
#     272     **kwargs: Any,
#     273 ) -> BaseMessage:
#     274     config = ensure_config(config)
#     275     return cast(
#     276         ChatGeneration,
# --> 277         self.generate_prompt(
#     278             [self._convert_input(input)],
#     279             stop=stop,
#     280             callbacks=config.get("callbacks"),
#     281             tags=config.get("tags"),
#     282             metadata=config.get("metadata"),
#     283             run_name=config.get("run_name"),
#     284             run_id=config.pop("run_id", None),
#     285             **kwargs,
#     286         ).generations[0][0],
#     287     ).message
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:777, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     769 def generate_prompt(
#     770     self,
#     771     prompts: List[PromptValue],
#    (...)
#     774     **kwargs: Any,
#     775 ) -> LLMResult:
#     776     prompt_messages = [p.to_messages() for p in prompts]
# --> 777     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:634, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     632         if run_managers:
#     633             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 634         raise e
#     635 flattened_outputs = [
#     636     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     637     for res in results
#     638 ]
#     639 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:624, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     621 for i, m in enumerate(messages):
#     622     try:
#     623         results.append(
# --> 624             self._generate_with_cache(
#     625                 m,
#     626                 stop=stop,
#     627                 run_manager=run_managers[i] if run_managers else None,
#     628                 **kwargs,
#     629             )
#     630         )
#     631     except BaseException as e:
#     632         if run_managers:
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:846, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     844 else:
#     845     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 846         result = self._generate(
#     847             messages, stop=stop, run_manager=run_manager, **kwargs
#     848         )
#     849     else:
#     850         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_community/chat_models/ollama.py:286, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     262 def _generate(
#     263     self,
#     264     messages: List[BaseMessage],
#    (...)
#     267     **kwargs: Any,
#     268 ) -> ChatResult:
#     269     """Call out to Ollama's generate endpoint.
#     270
#     271     Args:
#    (...)
#     283             ])
#     284     """
# --> 286     final_chunk = self._chat_stream_with_aggregation(
#     287         messages,
#     288         stop=stop,
#     289         run_manager=run_manager,
#     290         verbose=self.verbose,
#     291         **kwargs,
#     292     )
#     293     chat_generation = ChatGeneration(
#     294         message=AIMessage(content=final_chunk.text),
#     295         generation_info=final_chunk.generation_info,
#     296     )
#     297     return ChatResult(generations=[chat_generation])
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_community/chat_models/ollama.py:217, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     208 def _chat_stream_with_aggregation(
#     209     self,
#     210     messages: List[BaseMessage],
#    (...)
#     214     **kwargs: Any,
#     215 ) -> ChatGenerationChunk:
#     216     final_chunk: Optional[ChatGenerationChunk] = None
# --> 217     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     218         if stream_resp:
#     219             chunk = _chat_stream_response_to_chat_generation_chunk(stream_resp)
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/langchain_community/chat_models/ollama.py:189, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     179 def _create_chat_stream(
#     180     self,
#     181     messages: List[BaseMessage],
#     182     stop: Optional[List[str]] = None,
#     183     **kwargs: Any,
#     184 ) -> Iterator[str]:
#     185     payload = {
#     186         "model": self.model,
#     187         "messages": self._convert_messages_to_ollama_messages(messages),
#     188     }
# --> 189     yield from self._create_stream(
#     190         payload=payload, stop=stop, api_url=f"{self.base_url}/api/chat", **kwargs
#     191     )
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/requests/models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/requests/utils.py:572, in stream_decode_response_unicode(iterator, r)
#     569     return
#     571 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 572 for chunk in iterator:
#     573     rv = decoder.decode(chunk)
#     574     if rv:
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/urllib3/response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/urllib3/response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File ~/environemnts/tabular39/lib/python3.9/site-packages/urllib3/response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File /usr/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
annotated_results = cga_utils.annotate_results(res)
#annotated_results.to_csv('res/Ollama_2_gemma3n_e4b_code_values_v11_m1.csv')
cga_utils.calc_overall_value_match(annotated_results)
# Out:
# 0.5112936344969199

# %%
cga_utils.calc_overall_em(annotated_results), cga_utils.calc_overall_em_alt(annotated_results)
# Out:
# (0.38193018480492813, 0.38193018480492813)

# %%
annotated_results.to_csv('res/e40_18.csv')

# %%
df = ars[0].query('error_code != "none"')
cga_utils.crosstab_heatmap(df, 'error_code', 'calc_pattern', 40)
len(df)
# Out:
# 167
