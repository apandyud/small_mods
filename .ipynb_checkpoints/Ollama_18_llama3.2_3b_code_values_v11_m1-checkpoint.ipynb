# %%
# code gen + values list

#### import tatqa_utils
import pandas as pd
import table_convert
import pyreadstat
#from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

import utils
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
import numpy as np
from progress.bar import Bar
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from langchain_community.chat_models import ChatOllama
from langchain.schema import HumanMessage
llm = ChatOllama(model="llama3.2:1b")  # vagy bármely más elérhető Ollama modell

# %%
from langchain.globals import set_llm_cache
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
from langchain_community.cache import SQLiteCache

#llm = ChatOpenAI(temperature=0)
#llm = OpenAI(temperature=0) 
set_llm_cache(SQLiteCache(database_path=".langchain.ollama11.db"))

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
def get_question(qid):
    for i, item in devdf.iterrows():
        for q in item['questions']:        
            if q['uid'] == qid:
                #table = item['table']['table']
                return (item['table'], q)
    return (None, None)

# %%
import re

def extract_code_blocks(text):
    return "\n\n".join(re.findall(r'```(?:\w*\n)?(.*?)```', text, re.DOTALL))

def gen_code3(llm, messages, question, value_list): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"value_list": value_list, "question":question})
    print(response)
    code =  extract_code_blocks(response)
    
    return (prompt.format(value_list = value_list, question = question), code)

def exec_code(code, value_list):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({value_list})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

def gen_code_table(llm, messages, question, table): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"table": table, "question":question})
    code =  response.replace('```python','').replace('```','')
    
    return (prompt.format(table = table, question = question), code)

def exec_code_table(code, table):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({table})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

# %%
def get_answer(llm, messages, table, q):
    values = table_convert.convert_multitable(table)    
    p, code = gen_code3(llm, messages, q, values)    
    print("code:", code)
    (v, s) = exec_code(code, values)
    return  (v, s, code)

# %%
items = [i for idx, i in devdf.iterrows()]
item = items[1]
table = item['table']['table']
q = item.questions[4]
question = q['question']
#print(table, question)
r = get_answer(llm, prompt_versions.prompt_versions['V11'], table, question)
print(r[0], r[1], r[2])
# Out:
#
# ```python
# import math
#
# def run(value_list):
#     appliances = [x for x in value_list if x['category'] == 'Appliances']
#     result = sum([x['number_value'] - x['number_value'].year*1000 if x['scale'] == 'million' else (x['number_value'] - x['number_value'].year) / 1000 if x['scale'] == 'billion' else (x['number_value'] - x['number_value'].year) * 1000 if x['scale'] == 'thousand' else ((x['number_value'] - x['number_value'].year) / math.pow(10, x['scale'])) for x in appliances])
#     return result, ''
#
# value_list = [{'number_value': 1673.0, 'scale': 'million', 'category': 'Appliances'}, {'number_value': 1747.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 680.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 7821.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 685.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 682.0, 'scale': 'thousand', 'category': 'Appliances'},
#              {'number_value': 1673.0, 'scale': 'billion', 'category': 'Appliances'},
#              {'number_value': 1747.0, 'scale': 'billion', 'category': 'Appliances'}]
#
# result, _ = run(value_list)
# print(result)
# code:
# [Error]name 'run' is not defined
# [Error]name 'run' is not defined

# %%
from tqdm.notebook import tqdm as log_progress
import prompt_versions

devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')
cnt = 0
res = []
for i, item in log_progress(devdf.iterrows()):
    try:
        #if cnt == 36:
        #    break;
        #print(item['table']['uid'])
        table = item['table']['table']
        value_list = table_convert.convert_multitable(table)    
        text = '\n'.join( [p['text'] for p in item['paragraphs']])
        for q in item['questions']:        
            if q['answer_type'] == 'arithmetic' and 'table' == q['answer_from']:   
                cnt = cnt + 1
                print(q['uid'])
                _table, _q =  get_question(q['uid'])
                
                table = _table['table']
                
                #[print(r) for r in table]
                
                q = _q['question']
                print(q, end='')
                
                
                r = []
                #for i in [0,1,2]:        
                #   r.append(get_answer(llm, messages, table, q))
                
                #if r[0][0] == r[1][0]:
                #    (v, s) = r[0]
                #elif r[1][0] == r[2][0]:
                #    (v, s) = r[1]
                #elif r[0][0] == r[2][0]:
                #    (v, s) = r[0]
                #else:
                #    (v, s) = (None, None)
                    
                #(v, s, code) = get_answer(llm, messages, table, q)    
                (pred_value, pred_scale, code) = get_answer(llm, prompt_versions.prompt_versions['V11'], table, q)    
                
                if 'in millions' in text.lower() and pred_scale == '':
                    pred_scale = 'million'
                    
                if  utils.eval_predicted_value(pred_value, _q['answer']):
                    print("\033[92m Success: " + str(pred_value)+'\033[0m')
                else:    
                    print("\033[91m failure: " + str(pred_value), 'good answer: ', _q['answer'],'\033[0m' )
                
                if isinstance(pred_value, tuple) and len(pred_value) == 2:
                    print('$$$$')
                    (pred_value, pred_scale) = pred_value
                if pred_scale == "%" or pred_scale == "percentage"  :
                    pred_scale = 'percent'
                if pred_scale not in ["", 'thousand', 'million', 'billion', 'percent']:
                    print('Invalid ', pred_scale)
                    pred_scale = ""    
                #if item['table']['uid'] in res_scale and pred_scale != 'percent':
                #    pred_scale = res_scale[item['table']['uid']]
                err=""
                if isinstance(pred_value, str):
                    #print("string")
                    if  pred_value.startswith('[Error]'):
                        err = pred_value
                        (pred_value, pred_scale) = ("", "")
                                                                              
                res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, pred_value, pred_scale, _q, code, table,value_list, err))
    except Exception as e:
        s = '[Outer Exception]'+ str(e)
        print(s)
        res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, "", "", _q, "", table,"", s))
# Out:
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018?
# ```python
# import math
#
# def run(value_list):
#     appliances = [x for x in value_list if x['category'] == 'Appliances']
#     result = sum([x['number_value'] - x['number_value'].year*1000 if x['scale'] == 'million' else (x['number_value'] - x['number_value'].year) / 1000 if x['scale'] == 'billion' else (x['number_value'] - x['number_value'].year) * 1000 if x['scale'] == 'thousand' else ((x['number_value'] - x['number_value'].year) / math.pow(10, x['scale'])) for x in appliances])
#     return result, ''
#
# value_list = [{'number_value': 1673.0, 'scale': 'million', 'category': 'Appliances'}, {'number_value': 1747.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 680.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 7821.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 685.0, 'scale': 'million', 'category': 'Appliances'},
#              {'number_value': 682.0, 'scale': 'thousand', 'category': 'Appliances'},
#              {'number_value': 1673.0, 'scale': 'billion', 'category': 'Appliances'},
#              {'number_value': 1747.0, 'scale': 'billion', 'category': 'Appliances'}]
#
# result, _ = run(value_list)
# print(result)
# code:
# [Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  -94
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018?
# ```python
# def run(value_list):
#     for value in value_list:
#         if 'billion' in str(value['scale']):
#             return (value['number_value'], '')
#         elif 'million' in str(value['scale']):
#             return ((value['number_value'] / 1000), '',)
#         elif 'percent' in str(value['scale']):
#             return ((value['number_value'] / value['number_value']), 1, '')
#     raise ValueError('Unknown scale')
# ```
# code: def run(value_list):
#     for value in value_list:
#         if 'billion' in str(value['scale']):
#             return (value['number_value'], '')
#         elif 'million' in str(value['scale']):
#             return ((value['number_value'] / 1000), '',)
#         elif 'percent' in str(value['scale']):
#             return ((value['number_value'] / value['number_value']), 1, '')
#     raise ValueError('Unknown scale')
#
#  failure: 5.686 good answer:  -12.14
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019?
#
# ```python
# def run(value_list):
#     domestic_rate = float(value_list[0].number_value)
#     international_rate = float(value_list[1].number_value)
#
#     percent_diff = (domestic_rate - international_rate) / domestic_rate * 100
#
#     return (percent_diff, value_list[2].scale.replace(',', ''))
# ```
# code: def run(value_list):
#     domestic_rate = float(value_list[0].number_value)
#     international_rate = float(value_list[1].number_value)
#
#     percent_diff = (domestic_rate - international_rate) / domestic_rate * 100
#
#     return (percent_diff, value_list[2].scale.replace(',', ''))
#
# [Error]'dict' object has no attribute 'number_value'
#  failure: [Error]'dict' object has no attribute 'number_value' good answer:  2.1
# 4dc8be43-d8d9-4b08-9ffd-9c19012361ce
# What is the year on year percentage change in domestic discount rate between 2018 and 2019?
#
# ```python
# def run(value_list):
#     domestic_rates = [item['category'] for item in value_list if item['category'] == 'Discount rate' and item['number_value'].endswith('%')]
#     if not domestic_rates:
#         return None, ""
#
#     year_change_rate = 0.0
#
#     for i, rate in enumerate(domestic_rates):
#         year = int(rate.split(' ')[1].split('/')[0]) - int(rate.split(' ')[1].split('/')[2])
#
#         # Check the type of scale
#         if len(rate.split('%')[1].split(',')[0].replace('.', '', 1)) == 3:
#             scale = 'billion'
#         elif len(rate.split('%')[1].split(',')[0].replace('.', '', 1)) == 6:
#             scale = 'million'
#         elif len(rate.split('%')[1].split(',')[0].replace('.', '', 1)) == 9:
#             scale = 'thousand'
#         else:
#             scale = ""
#
#         year_change_rate += ((year - int(year / 100 * 2018)) / 100) * float(rate)
#
#     return round(year_change_rate, 2), f"{scale} thousand"
# ```
#
# Now I can provide the answer using this function with the provided financial report.
# code: def run(value_list):
#     domestic_rates = [item['category'] for item in value_list if item['category'] == 'Discount rate' and item['number_value'].endswith('%')]
#     if not domestic_rates:
#         return None, ""
#
#     year_change_rate = 0.0
#
#     for i, rate in enumerate(domestic_rates):
#         year = int(rate.split(' ')[1].split('/')[0]) - int(rate.split(' ')[1].split('/')[2])
#
#         # Check the type of scale
#         if len(rate.split('%')[1].split(',')[0].replace('.', '', 1)) == 3:
#             scale = 'billion'
#         elif len(rate.split('%')[1].split(',')[0].replace('.', '', 1)) == 6:
#             scale = 'million'
#         elif len(rate.split('%')[1].split(',')[0].replace('.', '', 1)) == 9:
#             scale = 'thousand'
#         else:
#             scale = ""
#
#         year_change_rate += ((year - int(year / 100 * 2018)) / 100) * float(rate)
#
#     return round(year_change_rate, 2), f"{scale} thousand"
#
# [Error]'float' object has no attribute 'endswith'
#  failure: [Error]'float' object has no attribute 'endswith' good answer:  6.67
# 6c44a1a8-0785-43a0-90ab-7e21df2c57d9
# What is the year on year percentage change in international expected return on plan assets between 2018 and 2019?
#
# ```python
# import re
#
# def run(value_list):
#     result = None
#     for value in value_list:
#         match = re.match(r'(\d+(?:\.\d+)?)([a-zA-Z]+) \(([0-9]{4})\)', str(value['number_value']))
#         if match:
#             number = float(match.group(1)) * 10000 if match.group(2) == 'percent' else float(match.group(1))
#             scale = match.group(3)
#             result = (round(number, 2), scale)
#     return result
# ```
# code: import re
#
# def run(value_list):
#     result = None
#     for value in value_list:
#         match = re.match(r'(\d+(?:\.\d+)?)([a-zA-Z]+) \(([0-9]{4})\)', str(value['number_value']))
#         if match:
#             number = float(match.group(1)) * 10000 if match.group(2) == 'percent' else float(match.group(1))
#             scale = match.group(3)
#             result = (round(number, 2), scale)
#     return result
#
# [Outer Exception]cannot unpack non-iterable NoneType object
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes?
# ```python
# def run(value_list):
#     value = value_list[0]
#     scale = value['scale']
#     number_value = float(value['number_value'])
#     if scale == '':
#         return (round(number_value / 1000000, 2), 'million')
#     elif scale == 'billion':
#         return (round(number_value / 1e9, 2), 'billon')
#     elif scale == 'percent':
#         return (round((number_value / 100) * 100, 2), '')
#     else:
#         return (round(number_value, 2), scale)
# ```
#
# This function will provide the answer to the question "What is the average defined contribution schemes?". The number value has a two decimal places accuracy and the scale can be 'million', 'billion' or 'percent'.
# code: def run(value_list):
#     value = value_list[0]
#     scale = value['scale']
#     number_value = float(value['number_value'])
#     if scale == '':
#         return (round(number_value / 1000000, 2), 'million')
#     elif scale == 'billion':
#         return (round(number_value / 1e9, 2), 'billon')
#     elif scale == 'percent':
#         return (round((number_value / 100) * 100, 2), '')
#     else:
#         return (round(number_value, 2), scale)
#
#  failure: 166.0 good answer:  172
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes?
#
# ```python
# def run(value_list):
#     numbers = [float(x['number_value']) for x in value_list]
#     scale_values = ['million', 'billion', 'trillion', '', '']
#
#     average_number = sum(numbers) / len(numbers)
#     average_scale = max(scale_values, key=lambda s: float(s.replace('million', '').replace('billion', '').strip()))
#
#     return (round(average_number, 2), average_scale)
#
# ```
#
# Let me know if you would like to run the function.
# code: def run(value_list):
#     numbers = [float(x['number_value']) for x in value_list]
#     scale_values = ['million', 'billion', 'trillion', '', '']
#
#     average_number = sum(numbers) / len(numbers)
#     average_scale = max(scale_values, key=lambda s: float(s.replace('million', '').replace('billion', '').strip()))
#
#     return (round(average_number, 2), average_scale)
#
#
# [Error]could not convert string to float: ''
#  failure: [Error]could not convert string to float: '' good answer:  50.5
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?
# ```
# def run(value_list):
#     number = value_list[0]['number_value']
#     scale = value_list[0]['scale']
#
#     if 'million' in scale:
#         return (number / 1000000, 'million')
#     elif 'billion' in scale:
#         return (number / 10**9, 'billion')
#     elif 'percent' in scale:
#         return ((number - value_list[1]['number_value']) / value_list[1]['number_value'] * 100)
#     elif scale == '':
#         return ('', '')
#     else:
#         raise ValueError('Invalid scale')
# ```
#
# This function should calculate the difference between the two average values of defined contribution and defined benefit schemes, taking into account their respective scales.
# code: def run(value_list):
#     number = value_list[0]['number_value']
#     scale = value_list[0]['scale']
#
#     if 'million' in scale:
#         return (number / 1000000, 'million')
#     elif 'billion' in scale:
#         return (number / 10**9, 'billion')
#     elif 'percent' in scale:
#         return ((number - value_list[1]['number_value']) / value_list[1]['number_value'] * 100)
#     elif scale == '':
#         return ('', '')
#     else:
#         raise ValueError('Invalid scale')
#
#  failure: 0.000166 good answer:  121.5
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019?
#
# ```python
# def run(value_list):
#     percentage_change = value_list[-1]['number_value'] * (value_list[-2]['number_value'] / value_list[-1]['number_value']) - 100.0
#     if value_list[-1]['scale'] == 'percent':
#         return ((percentage_change / 100) * 100, "billion")
#     else:
#         scale = [x for x in value_list[-1]['scale'].split('/') if x != '']
#         return ((percentage_change / (float(value_list[-2]['number_value'])/ float(value_list[-1]['number_value']))), f"{int((value_list[-2]['number_value'] / value_list[-1]['number_value']))}{' '*int(len(scale))}{scale[0]}{',' if scale else ''}")
# ```
# code: def run(value_list):
#     percentage_change = value_list[-1]['number_value'] * (value_list[-2]['number_value'] / value_list[-1]['number_value']) - 100.0
#     if value_list[-1]['scale'] == 'percent':
#         return ((percentage_change / 100) * 100, "billion")
#     else:
#         scale = [x for x in value_list[-1]['scale'].split('/') if x != '']
#         return ((percentage_change / (float(value_list[-2]['number_value'])/ float(value_list[-1]['number_value']))), f"{int((value_list[-2]['number_value'] / value_list[-1]['number_value']))}{' '*int(len(scale))}{scale[0]}{',' if scale else ''}")
#
#  failure: 674.8930817610063 good answer:  26.82
# Invalid  1 thousand,
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019?
#
# ```python
# def run(value_list):
#     if len(value_list) < 2:
#         raise ValueError("The list should contain at least two values")
#
#     operating_loss_carryforward = value_list[1]
#     net_deferred_tax_asset_2018 = value_list[0]
#     percent_change_in_net_deferred_tax_asset = round(((net_deferred_tax_asset_2019 - net_deferred_tax_asset_2018) / net_deferred_tax_asset_2018) * 100,2)
#
#     return (percent_change_in_net_deferred_tax_asset, "billion")
# ```
#
# Please provide the final answer. I will use this function in a further question to get the correct output of the percent change calculation.
# code: def run(value_list):
#     if len(value_list) < 2:
#         raise ValueError("The list should contain at least two values")
#
#     operating_loss_carryforward = value_list[1]
#     net_deferred_tax_asset_2018 = value_list[0]
#     percent_change_in_net_deferred_tax_asset = round(((net_deferred_tax_asset_2019 - net_deferred_tax_asset_2018) / net_deferred_tax_asset_2018) * 100,2)
#
#     return (percent_change_in_net_deferred_tax_asset, "billion")
#
# [Error]name 'net_deferred_tax_asset_2019' is not defined
#  failure: [Error]name 'net_deferred_tax_asset_2019' is not defined good answer:  2.98
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019?
# ```python
# def run(value_list):
#     total_assets = sum(val['number_value'] for val in value_list if val['category'] == 'Total assets')
#     total_liabilities = sum(val['number_value'] for val in value_list if val['category'] == 'Total liabilities')
#
#     ratio = round((total_assets / total_liabilities) * 100, 2)
#     if '$' in str(ratio):
#         return (ratio.replace('$', '').replace(',', ''), 'Billion')
#     elif 'M' in str(ratio):
#         return (ratio.replace('M', '').replace('$', '').replace(',', ''), 'Million')
#     elif 'T' in str(ratio):
#         return (ratio.replace('T', '').replace('$', '').replace(',', ''), 'Billion')
#     else:
#         return (ratio, '')
# ```
# code: def run(value_list):
#     total_assets = sum(val['number_value'] for val in value_list if val['category'] == 'Total assets')
#     total_liabilities = sum(val['number_value'] for val in value_list if val['category'] == 'Total liabilities')
#
#     ratio = round((total_assets / total_liabilities) * 100, 2)
#     if '$' in str(ratio):
#         return (ratio.replace('$', '').replace(',', ''), 'Billion')
#     elif 'M' in str(ratio):
#         return (ratio.replace('M', '').replace('$', '').replace(',', ''), 'Million')
#     elif 'T' in str(ratio):
#         return (ratio.replace('T', '').replace('$', '').replace(',', ''), 'Billion')
#     else:
#         return (ratio, '')
#
#  failure: 256.96 good answer:  2.93
# 263d03ec-83d2-48df-8376-1a72167798f7
# What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?
#
# ```python
# def run(value_list):
#     total_assets_2018 = value_list[1]['number_value']
#     total_property_equipment_2018 = value_list[2]['number_value']
#
#     property_equipment_proportion = (total_property_equipment_2018 / total_assets_2018) * 100
#
#     return ((round(property_equipment_proportion, 2)), 'billion')
# ```
# code: def run(value_list):
#     total_assets_2018 = value_list[1]['number_value']
#     total_property_equipment_2018 = value_list[2]['number_value']
#
#     property_equipment_proportion = (total_property_equipment_2018 / total_assets_2018) * 100
#
#     return ((round(property_equipment_proportion, 2)), 'billion')
#
#  failure: 140.66 good answer:  0.87
# 78fc6d55-c20c-4f71-99fe-bc40a16e61d0
# What is the change of IMFT’s total assets from 2018 to 2019?
# ```python
# def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and 'scale' in item:
#             total_asset_change = (item['number_value'] - item['number_value'].replace('.', '', 1)) / item['number_value']
#             return round(total_asset_change, 2), ''
#         elif 'scale' in item:
#             scale = item['scale']
#         else:
#             print(f"Unknown field: {item}")
#     return None
# ```
# code: def run(value_list):
#     for item in value_list:
#         if 'number_value' in item and 'scale' in item:
#             total_asset_change = (item['number_value'] - item['number_value'].replace('.', '', 1)) / item['number_value']
#             return round(total_asset_change, 2), ''
#         elif 'scale' in item:
#             scale = item['scale']
#         else:
#             print(f"Unknown field: {item}")
#     return None
#
# [Error]'float' object has no attribute 'replace'
#  failure: [Error]'float' object has no attribute 'replace' good answer:  -361
# a4f782f1-de3b-47a3-87af-1cb33c112b39
# What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?
#
# ```python
# import math
# def run(value_list):
#     value_2019 = next((v for v in value_list if v['category'] == 'Value added tax receivables, net, noncurrent (Note 20)', 'number_value' in v.keys()), None)
#     value_2018 = next((v for v in value_list if v['category'] == 'Value added tax receivables, net, noncurrent (Note 20)', 'number_value' not in v.keys() or not 'scale' in v.keys()), None)
#
#     percent_change = ((value_2019['number_value'] - value_2018['number_value']) / value_2018['number_value']) * 100
#     return round(percent_change, 2), 'billion'
#
# # Test the function
# financial_report = [{'number_value': 27973.0, 'scale': '', 'category': 'Value added tax receivables, net, noncurrent (Note 20)', 'header1': '2019', 'header2': 'December 31,'}, {'number_value': 27977.0, 'scale': '', 'category': 'Value added tax receivables, net, noncurrent (Note 20)', 'header1': '2018', 'header2': 'December 31,'}]
#
# print(run(financial_report))
# ```
#
# This function should return the required answer as a tuple of two float values.
# code: import math
# def run(value_list):
#     value_2019 = next((v for v in value_list if v['category'] == 'Value added tax receivables, net, noncurrent (Note 20)', 'number_value' in v.keys()), None)
#     value_2018 = next((v for v in value_list if v['category'] == 'Value added tax receivables, net, noncurrent (Note 20)', 'number_value' not in v.keys() or not 'scale' in v.keys()), None)
#
#     percent_change = ((value_2019['number_value'] - value_2018['number_value']) / value_2018['number_value']) * 100
#     return round(percent_change, 2), 'billion'
#
# # Test the function
# financial_report = [{'number_value': 27973.0, 'scale': '', 'category': 'Value added tax receivables, net, noncurrent (Note 20)', 'header1': '2019', 'header2': 'December 31,'}, {'number_value': 27977.0, 'scale': '', 'category': 'Value added tax receivables, net, noncurrent (Note 20)', 'header1': '2018', 'header2': 'December 31,'}]
#
# print(run(financial_report))
#
# [Error]invalid syntax (<string>, line 3)
#  failure: [Error]invalid syntax (<string>, line 3) good answer:  14.07
# dc5e217a-a7b3-4fc9-ac0f-13d328f26b20
# What is the 2019 average free cash flow?
#
# ```python
# def run(value_list):
#     numbers = [x['number_value'] for x in value_list]
#     averages = {'billion': lambda x: round(x / 1000, 2), 'million': lambda x: round(x / 1000000, 2),
#                'thousand': lambda x: f"{x // 1000:.2f}", 'percent': lambda x: f'{(x * 100):.2f}%'}
#     average = averages['billion'](numbers[0])
#     scale = [x for x in numbers if x != 0][0]['scale']
#     return (average, scale)
# ```
# code: def run(value_list):
#     numbers = [x['number_value'] for x in value_list]
#     averages = {'billion': lambda x: round(x / 1000, 2), 'million': lambda x: round(x / 1000000, 2),
#                'thousand': lambda x: f"{x // 1000:.2f}", 'percent': lambda x: f'{(x * 100):.2f}%'}
#     average = averages['billion'](numbers[0])
#     scale = [x for x in numbers if x != 0][0]['scale']
#     return (average, scale)
#
# [Error]'float' object is not subscriptable
#  failure: [Error]'float' object is not subscriptable good answer:  4227.5
# 7cd3aedf-1291-4fea-bc9d-a25c65727b7b
# What is the 2018 average free cash flow?
# ```python
# import math
#
# def run(value_list):
#     free_cash_flows = [float(val) for val in value_list if val['category'] == 'Free cash flow (pre-spectrum)']
#     average_free_cash_flow = sum(free_cash_flows) / len(free_cash_flows)
#     scale = ''
#     for val in value_list:
#         if val['scale'] == 'million' and val['number_value'] != 0:
#             scale += val['scale']
#         elif val['scale'] == 'billion':
#             scale += val['scale'].ljust(2, '0')
#         elif val['scale'] == '%':
#             scale = '-%.1f%%'.format(float(val['number_value']) / 100)
#     if scale:
#         return average_free_cash_flow, scale.strip()
#     else:
#         return average_free_cash_flow, ''
# ```
# Please give me a moment to test it.
# code: import math
#
# def run(value_list):
#     free_cash_flows = [float(val) for val in value_list if val['category'] == 'Free cash flow (pre-spectrum)']
#     average_free_cash_flow = sum(free_cash_flows) / len(free_cash_flows)
#     scale = ''
#     for val in value_list:
#         if val['scale'] == 'million' and val['number_value'] != 0:
#             scale += val['scale']
#         elif val['scale'] == 'billion':
#             scale += val['scale'].ljust(2, '0')
#         elif val['scale'] == '%':
#             scale = '-%.1f%%'.format(float(val['number_value']) / 100)
#     if scale:
#         return average_free_cash_flow, scale.strip()
#     else:
#         return average_free_cash_flow, ''
#
# [Error]float() argument must be a string or a number, not 'dict'
#  failure: [Error]float() argument must be a string or a number, not 'dict' good answer:  3680
# 22e20f25-669a-46b9-8779-2768ba391955
# What is the change between 2018 and 2019 average free cash flow?
#
# def run(value_list):
#     free_cash_flows = [value for value in value_list if 'Free cash flow' in str(value)]
#     if len(free_cash_flows) > 0:
#         average_free_cash_flow_2018 = sum(free_cash_flows)[1:] / len(free_cash_flows)
#         average_free_cash_flow_2019 = sum([value for value in free_cash_flows if 'Free cash flow' not in str(value)][1:]) / len([value for value in free_cash_flows if 'Free cash flow' not in str(value)])
#     else:
#         average_free_cash_flow_2018 = 0.0
#         average_free_cash_flow_2019 = 0.0
#
#     percentage_change = ((average_free_cash_flow_2019 - average_free_cash_flow_2018) / average_free_cash_flow_2018) * 100
#     if 'billion' in str(percentage_change):
#         return (round(float(str(percentage_change).replace(',', '')), 2), '')
#     elif 'million' in str(percentage_change):
#         return (round(float(str(percentage_change).replace(',', '')), 2), '')
#     elif percentage_change == 0:
#         return (0.0, '')
#     else:
#         return (float(percentage_change), '')
# code:
# [Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  547.5
# a983501d-2eec-486d-9661-e520c7c8af5e
# What was the average difference between EBITDA and underlying EBITDA for both FYs?
#
# def run(value_list):
#     EBITDA = [x['header1'] + x['number_value'] for x in value_list if x['category'].startswith('EBITDA')]
#     underlying_EBITDA = [x['header1'] + x['number_value'] for x in value_list if x['category'].startswith('Underlying EBITDA')]
#
#     ebitda_diff = []
#     avg_ebitda_diff = 0
#
#     for ebitda, underlying_ebitda in zip(EBITDA, underlying_EBITDA):
#         diff = (ebitda - underlying_ebitda) / (1 + underlying_ebitda)
#         if 'scale' in str(ebitda).lower():
#             scale = float(str(ebitda).split('.')[0])
#             ebitda_diff.append((diff * 1000, scale))
#         else:
#             ebitda_diff.append((diff, ''))
#
#     # calculating average difference
#     avg_diff = sum(x for x in ebitda_diff if x[1] != '')
#     if not ebitda_diff:
#         return (0.00, '')
#     else:
#         avg_ebitda_diff = round(sum([x[0] for x in ebitda_diff]) / len(ebitda_diff), 2)
#
#     # converting to string
#     ebitda_diff_str = [(str(x[0]), str(x[1])) if x[1].lower() != '' else (str(x[0]), '000')
#                     for x in ebitda_diff]
#
#     return tuple(sorted(ebitda_diff_str, key=lambda item: float(item[0]))))
# code:
# [Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  3728
# 64c902c6-f426-4432-84b3-c10b3065716f
# What was the difference in net profit between both FYs?
#
# ```python
# def run(value_list):
#     if len(value_list) < 2:
#         raise ValueError("Value list must contain at least two values.")
#
#     number_value = float(value_list[1]['number_value'])
#     scale = value_list[1]['scale']
#
#     if scale == '':
#         return (round(number_value, 2), 'billion')
#     else:
#         if scale.endswith('billion'):
#             return (round(number_value / 1000, 2), 'million')
#         elif scale.endswith('thousand'):
#             return (round(number_value / 1000, 2), 'hundred thousand')
#         elif scale.endswith('percent'):
#             return (number_value * 100.0, '')
#         else:
#             raise ValueError("Invalid scale value.")
# ```
# code: def run(value_list):
#     if len(value_list) < 2:
#         raise ValueError("Value list must contain at least two values.")
#
#     number_value = float(value_list[1]['number_value'])
#     scale = value_list[1]['scale']
#
#     if scale == '':
#         return (round(number_value, 2), 'billion')
#     else:
#         if scale.endswith('billion'):
#             return (round(number_value / 1000, 2), 'million')
#         elif scale.endswith('thousand'):
#             return (round(number_value / 1000, 2), 'hundred thousand')
#         elif scale.endswith('percent'):
#             return (number_value * 100.0, '')
#         else:
#             raise ValueError("Invalid scale value.")
#
#  failure: 6.64 good answer:  -16458
# Invalid  hundred thousand
# 91812b92-5e94-414f-a447-4622aa3c2d10
# What was the average dividend yield for the 3 years from 2017 to 2019?
#
# def run(value_list):
#     dividend_yields = []
#     for i in range(len(value_list) - 1):
#         if value_list[i]['category'] == 'Dividend yield':
#             dividend_yield = value_list[i]['number_value']
#             if value_list[i+1]:
#                 divisor = float(value_list[i+1]['header2'])
#             else:
#                 divisor = 1000
#             dividend_yields.append((dividend_yield / divisor, value_list[i+1]['scale']))
#     if len(dividend_yields) == 3:
#         average_dividend_yield, scale = dividend_yields[0]
#         avg_rate = round(average_dividend_yield,2)
#     else:
#         avg_rate = 'Unknown'
#         scale = ''
#     return (avg_rate, scale)
# code:
# [Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  1.57
# 29b63db7-4925-4629-b108-49bbb27fb565
# What was the average risk-free interest rate over the 3 year period from 2017 to 2019?
#
# ```python
# def run(value_list):
#     risk_free_rates = [v['number_value'] for v in value_list if 'risk-free interest rate' in v['category']]
#     avg_rate = sum(risk_free_rates) / len(risk_free_rates)
#     scale = ''
#     if 'billion' in avg_rate or 'million' in avg_rate:
#         scale = 'billion'
#     elif 'million' in avg_rate or 'thousand' in avg_rate:
#         scale = 'million'
#     else:
#         scale = ''
#     return (round(avg_rate, 2), scale)
# ```
# code: def run(value_list):
#     risk_free_rates = [v['number_value'] for v in value_list if 'risk-free interest rate' in v['category']]
#     avg_rate = sum(risk_free_rates) / len(risk_free_rates)
#     scale = ''
#     if 'billion' in avg_rate or 'million' in avg_rate:
#         scale = 'billion'
#     elif 'million' in avg_rate or 'thousand' in avg_rate:
#         scale = 'million'
#     else:
#         scale = ''
#     return (round(avg_rate, 2), scale)
#
# [Error]argument of type 'float' is not iterable
#  failure: [Error]argument of type 'float' is not iterable good answer:  1.9
# 6100c476-160a-4f1e-bfc1-a16f4cc18b52
# What was the increase / (decrease) in the cost from 2018 to 2019?
#
# ```python
# def run(value_list):
#     if len(value_list) < 2:
#         raise ValueError("At least two values are required")
#
#     number = value_list[1]['number_value']
#     scale = value_list[1]['scale']
#
#     if 'billion' in scale.lower():
#         num_scale = int(number / 1000)
#         percent_scale = f"{number}%"
#     elif 'million' in scale.lower() and 'thousand' not in scale:
#         num_scale = number // 1000
#         percent_scale = ''
#     else:
#         return run(value_list)
#
#     if len(scale) == 2 or scale == '':
#         result = f"{number:.2f} {percent_scale}"
#     else:
#         result = f"{num_scale}.{scale}{percent_scale}"
#
#     return float(result)
# ```
# code: def run(value_list):
#     if len(value_list) < 2:
#         raise ValueError("At least two values are required")
#
#     number = value_list[1]['number_value']
#     scale = value_list[1]['scale']
#
#     if 'billion' in scale.lower():
#         num_scale = int(number / 1000)
#         percent_scale = f"{number}%"
#     elif 'million' in scale.lower() and 'thousand' not in scale:
#         num_scale = number // 1000
#         percent_scale = ''
#     else:
#         return run(value_list)
#
#     if len(scale) == 2 or scale == '':
#         result = f"{number:.2f} {percent_scale}"
#     else:
#         result = f"{num_scale}.{scale}{percent_scale}"
#
#     return float(result)
#
# [Error]could not convert string to float: '0.0.million'
#  failure: [Error]could not convert string to float: '0.0.million' good answer:  18
# a81f1322-e74f-4e3c-a6cf-4b8d25d01cf5
# What is the average Selling, general and administrative?
#
# ```python
# def run(value_list):
#     for item in value_list:
#         if item['category'] == 'Selling, general and administrative':
#             return (item['number_value'], '')
#
#     raise ValueError("No Selling, general and administrative values found.")
# ```
# code: def run(value_list):
#     for item in value_list:
#         if item['category'] == 'Selling, general and administrative':
#             return (item['number_value'], '')
#
#     raise ValueError("No Selling, general and administrative values found.")
#
#  failure: 453.0 good answer:  399.33
# f7cac790-05ae-4a55-a41d-836a6b415f88
# What is the percentage increase / (decrease) of Research, development and engineering from 2018 to 2019?
#
# ```python
# def run(value_list):
#     research_dev_2019 = value_list[1]
#     research_dev_2018 = value_list[2]
#
#     increase = (research_dev_2019 - research_dev_2018) / research_dev_2018 if research_dev_2018 != 0 else 0.00
#     decrease = research_dev_2018
#
#     result_scale = 'million' if research_dev_2019 > research_dev_2018 else \
#                    'thousand' if research_dev_2019 == research_dev_2018 else \
#                    ''
#
#     return (round(increase, 2), result_scale)
# ```
#
# You can now test it with your example value list.
# code: def run(value_list):
#     research_dev_2019 = value_list[1]
#     research_dev_2018 = value_list[2]
#
#     increase = (research_dev_2019 - research_dev_2018) / research_dev_2018 if research_dev_2018 != 0 else 0.00
#     decrease = research_dev_2018
#
#     result_scale = 'million' if research_dev_2019 > research_dev_2018 else \
#                    'thousand' if research_dev_2019 == research_dev_2018 else \
#                    ''
#
#     return (round(increase, 2), result_scale)
#
# [Error]unsupported operand type(s) for -: 'dict' and 'dict'
#  failure: [Error]unsupported operand type(s) for -: 'dict' and 'dict' good answer:  88.06
# 65ec782c-691e-45df-b541-caecb85154ff
# What was the change in Capital redemption reserve in 2019 from 2018?
#
# ```python
# def run(value_list):
#     total_cap_redeemed = sum(item['number_value'] for item in value_list if 'redundancy' not in item)
#     capital_redemption reserves 2019 = round(total_cap_redeemed,2) - round(0,2)
#
#     return (capital_redemption_reserves, '')
# code:
# [Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  0.2
# 94916f79-4b6d-487f-8fa2-39f81a085760
# What was the percentage change in Capital redemption reserve in 2019 from 2018?
# ```python
# def run(value_list):
#     if 'redemption reserve' in [x['category'] for x in value_list]:
#         redemption_reserve_2019 = sum(x.get('number_value', 0) for x in value_list if x.get('category') == 'Capital redemption reserve')
#         scale = 'million'
#     elif any(category in ['Retained earnings', 'Called-up share capital'] for category in value_list):
#         retained_earnings_2019 = sum(x.get('number_value', 0) for x in value_list if x.get('category') == 'Retained earnings' or x.get('category') == 'Called-up share capital')
#         scale = 'million'
#     else:
#         raise ValueError("No redemption reserve or retained earnings found")
#
#     percentage_change = round((redemption_reserve_2019 / retention_earnings_2019) * 100, 2)
#     return round(percentage_change, 2), scale
# ```
#
# I would like to know what is the output of this function with your example input.
# code: def run(value_list):
#     if 'redemption reserve' in [x['category'] for x in value_list]:
#         redemption_reserve_2019 = sum(x.get('number_value', 0) for x in value_list if x.get('category') == 'Capital redemption reserve')
#         scale = 'million'
#     elif any(category in ['Retained earnings', 'Called-up share capital'] for category in value_list):
#         retained_earnings_2019 = sum(x.get('number_value', 0) for x in value_list if x.get('category') == 'Retained earnings' or x.get('category') == 'Called-up share capital')
#         scale = 'million'
#     else:
#         raise ValueError("No redemption reserve or retained earnings found")
#
#     percentage_change = round((redemption_reserve_2019 / retention_earnings_2019) * 100, 2)
#     return round(percentage_change, 2), scale
#
# [Error]No redemption reserve or retained earnings found
#  failure: [Error]No redemption reserve or retained earnings found good answer:  40
# bbe335ff-414f-48b3-8126-5a2c7c505de3
# How much was the average operating income from 2015 to 2019?
#
# ```python
# def run(value_list):
#     if value_list:
#         numbers = [x['number_value'] for x in value_list]
#         scales = [x['scale'] for x in value_list]
#
#         average Operating_income = round(sum(numbers) / len(numbers), 2)
#
#         return average Operating_income, 'million'
#     else:
#         return None, ''
# ```
#
# Please provide the annotated values list.
# code: def run(value_list):
#     if value_list:
#         numbers = [x['number_value'] for x in value_list]
#         scales = [x['scale'] for x in value_list]
#
#         average Operating_income = round(sum(numbers) / len(numbers), 2)
#
#         return average Operating_income, 'million'
#     else:
#         return None, ''
#
# [Error]invalid syntax (<string>, line 6)
#  failure: [Error]invalid syntax (<string>, line 6) good answer:  13237.4
# ef274d2b-fbd6-4e9f-95f9-79b37827d91c
# What was the total expenses for Oracle in 2018?
# ```python
# def run(value_list):
#     total_expenses = sum(val['number_value'] for val in value_list)
#     return round(total_expenses / 1000000, 2), ''
# ```
#
# Please provide the list of annotated values!
# code: def run(value_list):
#     total_expenses = sum(val['number_value'] for val in value_list)
#     return round(total_expenses / 1000000, 2), ''
#
#  failure: 1.42 good answer:  35796
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492
# What were the total Assets as reported?
#
# ```python
# import math
#
# def run(value_list):
#     total = sum(item['number_value'] for item in value_list)
#     scale = 'Thousand' if value_list[0]['scale'].startswith('m') else \
#               'Million' if value_list[0]['scale'].startswith('M') else \
#               'Billion' if value_list[0]['scale'].startswith('b') else \
#               ''
#     return total, scale
# ```
# code: import math
#
# def run(value_list):
#     total = sum(item['number_value'] for item in value_list)
#     scale = 'Thousand' if value_list[0]['scale'].startswith('m') else \
#               'Million' if value_list[0]['scale'].startswith('M') else \
#               'Billion' if value_list[0]['scale'].startswith('b') else \
#               ''
#     return total, scale
#
#  failure: 228178.0 good answer:  64509
# bd2d81eb-46fc-4e62-908d-aebfccf46246
# What were the total Liabilities and Stockholders' Equity as reported?
# ```python
# import pandas as pd
# def run(value_list):
#     df = pd.DataFrame(value_list)
#     result_dict = {'Liabilities and Stockholders\' Equity': ['Stockholders\' equity:' + str(round(df.loc[df['category'] == 'Prepaid expenses and other current assets (1)', 'number_value'), 2))]}
#     for category in value_list:
#         if category not in result_dict.keys():
#             result_dict[category] = [round(df.loc[df['category'] == category, 'number_value'], 2)]
#     return tuple(result_dict.values())
# ```
#
# The function will now be ready to use.
# code: import pandas as pd
# def run(value_list):
#     df = pd.DataFrame(value_list)
#     result_dict = {'Liabilities and Stockholders\' Equity': ['Stockholders\' equity:' + str(round(df.loc[df['category'] == 'Prepaid expenses and other current assets (1)', 'number_value'), 2))]}
#     for category in value_list:
#         if category not in result_dict.keys():
#             result_dict[category] = [round(df.loc[df['category'] == category, 'number_value'], 2)]
#     return tuple(result_dict.values())
#
# [Error]closing parenthesis ')' does not match opening parenthesis '[' (<string>, line 4)
#  failure: [Error]closing parenthesis ')' does not match opening parenthesis '[' (<string>, line 4) good answer:  62740
# 010df393-a62e-408d-888a-045a4e435e6a
# What is the difference in amount between Deferred Revenue and Other non-current liabilities as reported?

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)

# %%
import re
res2 = []
for ans, pred, pred_scale, q,code, table,value_list,err in res:
    good = utils.eval_predicted_value(pred, ans['answer'])
    regex = re.compile("\\(\\d+,?\\d+", re.VERBOSE)    
    match = regex.search(str(table))
    
    match = match != None
    if pred == None:
        pred = 0
    res2.append( {'qid': q['uid'], 'question' : q['question'], 'derivation': q['derivation'], 'pred' : pred, 'pred_scale': pred_scale,  'answer': ans['answer'],  'scale':  ans['scale'],  'abs': 'abs(' in code, 'inv' : ans['answer'] == -1*pred,  'good': good, 'parenth': match})
res2 = pd.DataFrame(res2)
print(len(res2.query('good == True'))/len(res2))
# Out:
# 0.026915113871635612

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [-1.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [4044.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [2349.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [16458.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [995.7],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12122000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [6.47],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [56.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [17.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [5309.6],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [244800.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-568.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [259.8],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-6841.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [63888.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.69999999999993],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [1303.1],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [8.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [-153391.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9307.75],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [201554.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
# ...
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [3695.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [4.52],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [-63.99],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1581.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [48784.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [1.32],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [36694.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [1.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [36.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
metrics._details[0]['pred'][0] == -94
# Out:
# True

# %%
scale_err =  [item for item in metrics._details if item['em'] != 1.0 and item['pred_scale'] != item['scale']]
only_scale_err =  [item for item in metrics._details if item['em'] != 1.0 and isinstance(item['pred'], list)  and  item['pred'][0] == item['answer']]
err =  [item for item in metrics._details if item['em'] != 1.0]
len (metrics._details), len(err), len(scale_err), len(only_scale_err)
# Out:
# (166, 56, 31, 20)

# %%
res = {}
for item in metrics._details:
  

    pred = item['pred']
    pred_scale = item['pred_scale']

    key = pred_scale +'|' + item['scale']
    if key not in res:
        res [key] = 1
    res[key]=res[key] +1


    if  item['em'] == 1.0:
        None
        #print("\033[92m Success: " + str(pred)+'\033[0m')
    else:           
 
        
        if isinstance(item['pred'], list) and  pred[0] == item['answer']:
           
            print("\033[93m", '|', " failure: ", '| ',str(pred[0]),  '| ', str(pred_scale), '| ', 'good answer: ', '| ', item['answer'], '| ', item['scale'], '\033[0m' )
        else:    
            None
            #print("\033[91m failure: " + str(pred),  str(pred_scale), 'good answer: ',item['answer'],item['scale'], '\033[0m' )
# Out:
#  |  failure:  |  62740.0 |   |  good answer:  |  62740 |  thousand
#  |  failure:  |  -19411.0 |   |  good answer:  |  -19411 |  thousand
#  |  failure:  |  12085176.0 |  thousand |  good answer:  |  12085176 |
#  |  failure:  |  28747.0 |  thousand |  good answer:  |  28747 |
#  |  failure:  |  113000.0 |  thousand |  good answer:  |  113000 |
#  |  failure:  |  111.4 |  million |  good answer:  |  111.4 |
#  |  failure:  |  107.15 |  million |  good answer:  |  107.15 |
#  |  failure:  |  -27603.0 |  thousand |  good answer:  |  -27603 |
#  |  failure:  |  3.0 |  million |  good answer:  |  3 |
#  |  failure:  |  -10029.67 |   |  good answer:  |  -10029.67 |  thousand
#  |  failure:  |  39.33 |  million |  good answer:  |  39.33 |
#  |  failure:  |  0.08 |  thousand |  good answer:  |  0.08 |  percent
#  |  failure:  |  16767.0 |   |  good answer:  |  16767 |  thousand
#  |  failure:  |  0.1 |   |  good answer:  |  0.1 |  million
#  |  failure:  |  54633874 |  thousand |  good answer:  |  54633874 |
#  |  failure:  |  0.18 |  thousand |  good answer:  |  0.18 |
#  |  failure:  |  0.97 |  thousand |  good answer:  |  0.97 |
#  |  failure:  |  3695.0 |  million |  good answer:  |  3695 |  thousand
#  |  failure:  |  39.3 |  million |  good answer:  |  39.3 |  percent
#  |  failure:  |  2.65 |  thousand |  good answer:  |  2.65 |
#  |  failure:  |  -0.2 |  million |  good answer:  |  -0.2 |  percent
#  |  failure:  |  1336.7 |  thousand |  good answer:  |  1336.7 |

# %%
res
# Out:
# {'million|million': 121,
#  'percent|percent': 177,
#  '|': 65,
#  'thousand|thousand': 82,
#  '|thousand': 11,
#  '|percent': 14,
#  'percent|': 3,
#  '|million': 5,
#  'thousand|': 11,
#  'million|percent': 5,
#  'million|': 9,
#  'thousand|percent': 2,
#  'billion|billion': 4,
#  'million|thousand': 2}

# %%
res
# Out:
# {'|thousand': 5,
#  'thousand|': 10,
#  'million|': 4,
#  'thousand|percent': 2,
#  '|million': 7,
#  'million|thousand': 2,
#  'million|percent': 3}

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [121.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [3680.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [3728.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [88.45],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12136.91],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [0.95],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [-56.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [-17.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': [2.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [4859.25],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [36.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-615.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [112.5],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-16105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [42592.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': [0.18],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [700.45],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [113.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [-9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9548.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [100777.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61,
#   'scale': 'percent',
#   'pred': [61.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 622908,
#   'scale': 'thousand',
#   'pred': [623111.0],
# ...
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 202845,
#   'scale': '',
#   'pred': [202845.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [11085.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [42.23],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [36.01],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1022.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [28101.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [-1.32],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [61584.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [0.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [100.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]
