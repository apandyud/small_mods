# %%
# code gen + values list

#### import tatqa_utils
import pandas as pd
import table_convert
import pyreadstat
#from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

import utils
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
import numpy as np
from progress.bar import Bar
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from langchain_community.chat_models import ChatOllama
from langchain.schema import HumanMessage
llm = ChatOllama(model="llama3.2:3b")  # vagy bármely más elérhető Ollama modell

# %%
from langchain.globals import set_llm_cache
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
from langchain_community.cache import SQLiteCache

#llm = ChatOpenAI(temperature=0)
#llm = OpenAI(temperature=0) 
set_llm_cache(SQLiteCache(database_path=".langchain.ollama18.db"))

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
def get_question(qid):
    for i, item in devdf.iterrows():
        for q in item['questions']:        
            if q['uid'] == qid:
                #table = item['table']['table']
                return (item['table'], q)
    return (None, None)

# %%
import re

def extract_code_blocks(text):
    return "\n\n".join(re.findall(r'```(?:\w*\n)?(.*?)```', text, re.DOTALL))

def gen_code3(llm, messages, question, value_list): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"value_list": value_list, "question":question})
    #print(response)
    code =  extract_code_blocks(response)
    
    return (prompt.format(value_list = value_list, question = question), code)

def exec_code(code, value_list):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({value_list})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

def gen_code_table(llm, messages, question, table): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"table": table, "question":question})
    code =  response.replace('```python','').replace('```','')
    
    return (prompt.format(table = table, question = question), code)

def exec_code_table(code, table):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({table})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

# %%
def get_answer(llm, messages, table, q):
    values = table_convert.convert_multitable(table)    
    p, code = gen_code3(llm, messages, q, values)    
    #print("code:", code)
    (v, s) = exec_code(code, values)
    return  (v, s, code)

# %%
import prompt_versions
items = [i for idx, i in devdf.iterrows()]
item = items[1]
table = item['table']['table']
q = item.questions[4]
question = q['question']
#print(table, question)
r = get_answer(llm, prompt_versions.prompt_versions['V11'], table, question)
print(r[0], r[1], r[2])
# Out:
# 94.0 million def run(value_list):
#     for item in value_list:
#         if item['category'] == 'Appliances' and item['header3'] == '2019':
#             prev_item = next((i for i in reversed(value_list) if i['category'] == 'Appliances' and i['header3'] == '2018'), None)
#             return (round(abs(item['number_value'] - prev_item['number_value']), 2), item['scale'])
#     return None

# %%
from tqdm.notebook import tqdm as log_progress
import prompt_versions

devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')
cnt = 0
res = []
for i, item in log_progress(devdf.iterrows()):
    try:
        #if cnt == 36:
        #    break;
        #print(item['table']['uid'])
        table = item['table']['table']
        value_list = table_convert.convert_multitable(table)    
        text = '\n'.join( [p['text'] for p in item['paragraphs']])
        for q in item['questions']:        
            if q['answer_type'] == 'arithmetic' and 'table' == q['answer_from']:   
                cnt = cnt + 1
                print(q['uid'])
                _table, _q =  get_question(q['uid'])
                
                table = _table['table']
                
                #[print(r) for r in table]
                
                q = _q['question']
                print(q, end='')
                
                
                r = []
                #for i in [0,1,2]:        
                #   r.append(get_answer(llm, messages, table, q))
                
                #if r[0][0] == r[1][0]:
                #    (v, s) = r[0]
                #elif r[1][0] == r[2][0]:
                #    (v, s) = r[1]
                #elif r[0][0] == r[2][0]:
                #    (v, s) = r[0]
                #else:
                #    (v, s) = (None, None)
                    
                #(v, s, code) = get_answer(llm, messages, table, q)    
                (pred_value, pred_scale, code) = get_answer(llm, prompt_versions.prompt_versions['V11'], table, q)    
                
                if 'in millions' in text.lower() and pred_scale == '':
                    pred_scale = 'million'
                    
                if  utils.eval_predicted_value(pred_value, _q['answer']):
                    print("\033[92m Success: " + str(pred_value)+'\033[0m')
                else:    
                    print("\033[91m failure: " + str(pred_value), 'good answer: ', _q['answer'],'\033[0m' )
                
                if isinstance(pred_value, tuple) and len(pred_value) == 2:
                    print('$$$$')
                    (pred_value, pred_scale) = pred_value
                if pred_scale == "%" or pred_scale == "percentage"  :
                    pred_scale = 'percent'
                if pred_scale not in ["", 'thousand', 'million', 'billion', 'percent']:
                    print('Invalid ', pred_scale)
                    pred_scale = ""    
                #if item['table']['uid'] in res_scale and pred_scale != 'percent':
                #    pred_scale = res_scale[item['table']['uid']]
                err=""
                if isinstance(pred_value, str):
                    #print("string")
                    if  pred_value.startswith('[Error]'):
                        err = pred_value
                        (pred_value, pred_scale) = ("", "")
                                                                              
                res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, pred_value, pred_scale, _q, code, table,value_list, err))
    except Exception as e:
        s = '[Outer Exception]'+ str(e)
        print(s)
        res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, "", "", _q, "", table,"", s))
# Out:
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018? failure: 94.0 good answer:  -94
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018? failure: -25.93 good answer:  -12.14
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019? Success: 2.1
# 4dc8be43-d8d9-4b08-9ffd-9c19012361ce
# What is the year on year percentage change in domestic discount rate between 2018 and 2019? failure: 0.0 good answer:  6.67
# 6c44a1a8-0785-43a0-90ab-7e21df2c57d9
# What is the year on year percentage change in international expected return on plan assets between 2018 and 2019? failure: 8.82 good answer:  -8.11
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes? failure: 0.0 good answer:  172
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes?[Error]division by zero
#  failure: [Error]division by zero good answer:  50.5
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes? failure: 109.0 good answer:  121.5
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019?[Error]Change only possible in operating loss carryforward category
#  failure: [Error]Change only possible in operating loss carryforward category good answer:  26.82
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019? failure: -2.89 good answer:  2.98
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019?[Error]unsupported operand type(s) for /: 'NoneType' and 'NoneType'
#  failure: [Error]unsupported operand type(s) for /: 'NoneType' and 'NoneType' good answer:  2.93
# 263d03ec-83d2-48df-8376-1a72167798f7
# What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?[Error]1
#  failure: [Error]1 good answer:  0.87
# 78fc6d55-c20c-4f71-99fe-bc40a16e61d0
# What is the change of IMFT’s total assets from 2018 to 2019? Success: -361.0
# a4f782f1-de3b-47a3-87af-1cb33c112b39
# What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018? failure: 0.0 good answer:  14.07
# dc5e217a-a7b3-4fc9-ac0f-13d328f26b20
# What is the 2019 average free cash flow? failure: 4447.83 good answer:  4227.5
# 7cd3aedf-1291-4fea-bc9d-a25c65727b7b
# What is the 2018 average free cash flow? failure: 57691.67 good answer:  3680
# 22e20f25-669a-46b9-8779-2768ba391955
# What is the change between 2018 and 2019 average free cash flow?[Outer Exception]cannot unpack non-iterable float object
# a983501d-2eec-486d-9661-e520c7c8af5e
# What was the average difference between EBITDA and underlying EBITDA for both FYs? failure: (-6.0, '') good answer:  3728
# $$$$
# 64c902c6-f426-4432-84b3-c10b3065716f
# What was the difference in net profit between both FYs? failure: 9571.0 good answer:  -16458
# 91812b92-5e94-414f-a447-4622aa3c2d10
# What was the average dividend yield for the 3 years from 2017 to 2019? Success: 1.57
# 29b63db7-4925-4629-b108-49bbb27fb565
# What was the average risk-free interest rate over the 3 year period from 2017 to 2019? Success: 1.9
# 6100c476-160a-4f1e-bfc1-a16f4cc18b52
# What was the increase / (decrease) in the cost from 2018 to 2019? Success: 18.0
# a81f1322-e74f-4e3c-a6cf-4b8d25d01cf5
# What is the average Selling, general and administrative? Success: 399.33
# f7cac790-05ae-4a55-a41d-836a6b415f88
# What is the percentage increase / (decrease) of Research, development and engineering from 2018 to 2019? Success: 88.06
# 65ec782c-691e-45df-b541-caecb85154ff
# What was the change in Capital redemption reserve in 2019 from 2018?[Outer Exception]cannot unpack non-iterable NoneType object
# bbe335ff-414f-48b3-8126-5a2c7c505de3
# How much was the average operating income from 2015 to 2019? failure: 13237400000.00 good answer:  13237.4
# ef274d2b-fbd6-4e9f-95f9-79b37827d91c
# What was the total expenses for Oracle in 2018? failure:  good answer:  35796
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492
# What were the total Assets as reported? failure: 35800.0 good answer:  64509
# bd2d81eb-46fc-4e62-908d-aebfccf46246
# What were the total Liabilities and Stockholders' Equity as reported?[Error]
#  failure: [Error] good answer:  62740
# 010df393-a62e-408d-888a-045a4e435e6a
# What is the difference in amount between Deferred Revenue and Other non-current liabilities as reported?[Error]list index out of range
#  failure: [Error]list index out of range good answer:  14212
# 58adf6c4-41ae-4f3f-84cb-cf3469a80ce4
# What was the percentage change in Total Other operating expenses between 2018 and 2019? failure: None good answer:  -67.6
# 79f06004-f4fc-4e82-a9fe-3c389a2f81b6
# What was the change in the statutory federal income tax rate from 2018 to 2019? Success: 0.0
# Invalid  0.0
# a360cee9-ce60-4f29-988d-8c6c627bb51f
# What was the average State and local income tax rate, net of federal tax benefits between 2017-2019? Success: 3.0
# 5c8c999e-354f-4693-9b2d-29e3c03cb2af
# What was the change in the preferred stock disposition from 2018 to 2019? failure: -1019400000.0 good answer:  -9.9
# 6cc73a99-0323-40d5-9d92-b285579b3482
# What was the percentage change in gross profit between 2018 and 2019? Success: -13.66
# fa43e8cd-7fea-4738-85ee-f61ae8529f96
# What was the change in the revenues from 2018 to 2019?[Error]
#  failure: [Error] good answer:  -21.7
# 2067daa1-9905-456b-bcbf-42bc66b47259
# What is the average net income for 2018 and 2019? Success: 88.45
# a1912c87-d68c-42ea-b0da-98908097d227
# What was the change in closing cash?[Error]'bool' object is not an iterator
#  failure: [Error]'bool' object is not an iterator good answer:  61.6
# 692ea65a-9a60-4210-bd75-d34231e2e113
# What is the average total current tax expense for 2017 and 2018? [Error]'float' object is not subscriptable
#  failure: [Error]'float' object is not subscriptable good answer:  984
# 7cba7400-af25-4f71-a49d-35d5eec31458
# What is the average total current tax expense for 2018 and 2019? failure: 1008.0 good answer:  1040
# 94ef7822-a201-493e-b557-a640f4ea4d83
# What is the change in the average total current tax expense between 2017-2018, and 2018-2019?[Outer Exception]cannot unpack non-iterable NoneType object
# bfce0375-cbd0-4e25-9b82-0424058918f1
# What is the total number of nonvested shares as of December 31, 2019 and 2018? failure: 0.01 good answer:  12122
# 73693527-ed4b-4d07-941e-0e654095a43d
# What was the employee termination costs as a proportion of total costs in 2018? failure: 2523.81 good answer:  0.9500000000000001
# 4a253bf4-b9fc-4ec3-b99b-d2744646a296
# What was the change in Total (loan) in 2019 from 2018? Success: -56.5
# 74183d5d-7633-43b5-bd7b-f0894fbe2299
# What was the percentage change in Total (loan) in 2019 from 2018? failure: -0.84 good answer:  -6.38
# 1238d807-aa57-48a3-93b6-591873788625
# What was the increase / (decrease) in the Statutory federal income tax (benefit) from 2018 to 2019? failure: -0.57 good answer:  -19411
# ef9d4839-5277-4614-bb73-f902fd8a38b6
# What was the average Tax exempt interest income? Success: -168.0
# fec503e8-6f91-483e-856d-bb1278bd031f
# What was the percentage change in the Domestic manufacturers deduction from 2017 to 2018? Success: -162.15
# a3e21403-222e-4328-8f7d-9383d2d91fe9
# What is the average dividend yield in 2017 and 2018?[Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  4.35
# a3637ae4-b286-44a5-a115-83867e4bb14e
# What is the average dividend yield in 2018 and 2019? failure: 10.77 good answer:  4.55
# d3f04ae4-ced9-446d-87b7-bb9d193e3603
# What is the average expected volatility in 2017 and 2018? Success: 27.9
# 8b6a4479-3b77-4db7-a90c-8b1ca41a8997
# What was the change in net debt from 2018 to 2019? failure: 0 good answer:  59.4
# 7b2b17a9-6409-45fb-907f-270832305974
# What was the percentage change in net debt from 2018 to 2019?[Outer Exception]cannot unpack non-iterable float object
# 3b5bb347-41c7-499a-b044-87b9a04b0833
# What was the percentage change in Total Other in 2018 from 2017? Success: 15.85
# 0d0c77cf-d32c-4b0e-8da0-dcaa3f681f59
# What is the percentage of Bell Wireless out of the Total BCE operating revenues in Q4 2019? failure: 19.73 good answer:  39.47
# 259e18e8-4738-4f4d-b625-e352ca78a136
# What is the increase / (decrease) in the recorded investment from 2018 to 2019? failure: 0.0 good answer:  -8736
# 407d43ea-c405-4b88-95ae-d15b1f25fb25
# What is the average Specific allowance for credit losses? Success: 198.5
# 681dcc0f-a32e-46ca-9785-1289a6aba802
# What is the percentage increase / (decrease) in the Net financing receivables from 2018 to 2019?[Error]list index out of range
#  failure: [Error]list index out of range good answer:  -28.05
# d2969c34-708e-4ab0-8e21-32c0b18c544c
# What is the ratio of current deferred revenue to non-current deferred revenue as of end of period? Success: 1.3
# 59f13f19-4494-4c54-8e9a-1b499d50021a
# What is the total price of shares that were exercised or canceled between 2016 and 2017? failure: -1870974.87 good answer:  981341.34
# b382a11b-749b-425a-a77d-20e943e00f77
# What is the proportion of granted shares between 2017 and 2018 over outstanding shares at September 30, 2017? failure: 0.0 good answer:  0.11
# 741f8b2e-9312-4426-893d-69b99fab247b
# What is the price of outstanding shares on September 30, 2019?[Outer Exception]cannot unpack non-iterable float object
# cf89ffee-b551-4e34-9321-30325df32cc1
# What was the change in the Amount recognized in other comprehensive (loss) income from 2017 to 2018? failure: 275000000.0 good answer:  -17
# 147f7c09-a627-4719-93ad-33661b5a4543
# What was the change in Total interest expense, net presented in the consolidated statements of income in which the effects of cash flow hedges are recorded between 2017 and 2018? failure: -0.0 good answer:  -2
# 6a441650-9d8a-43a0-8906-bec97a73ca2c
# What is the total special termination benefits charge in 2018 and 2019? failure: 0.0 million good answer:  21
# eb1ecc18-e3d3-4dd6-a689-546998eb2784
# What is the percentage change in interest cost in 2019 from 2018?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  failure: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType' good answer:  11.22
# 8a21f821-eaf6-421a-8c67-795e7e2d1f61
# What was the percentage change in Adjusted EBITDA between 2018 and 2019? Success: 16.36
# 07ec204e-3922-4b5c-b1fd-9cb9311a53e5
# What was the percentage change in the Total net deferred tax assets between 2018 and 2019? failure: 55,642 good answer:  -22.26
# f1034ee7-b182-48d5-bad8-1d9902500f57
# What is the difference in the number of rights 'granted during the period' between 2018 and 2019? failure: 0.00 good answer:  1226114
# 545cb01f-9b10-4a1b-8a7c-e9e74e725b26
# What is the average number of rights 'outstanding at end of period' for 2018 and 2019? failure: (10692594.0, 13477758.0) good answer:  12085176
# $$$$
# Invalid  13477758.0
# cc053817-3496-48b3-9bfc-83e9ba71bb57
# What is the percentage increase in the number of rights 'outstanding at the start of period' from 2018 to 2019?  Success: 58.71
# fda3b0cb-bc87-4cbc-bc8f-79604538a700
# What is the average Legal reserve within Appropriation of earnings? Success: 835623.0
# 8d8c9fb6-6316-4fad-881e-7cdb3cfa965a
# What is the increase/ (decrease) in Legal reserve within Appropriation of earnings from 2018 to 2019?[Error]invalid syntax (<string>, line 8)
#  failure: [Error]invalid syntax (<string>, line 8) good answer:  256648
# b4aabd48-5010-425f-be30-c63f1c648c85
# What is the increase/ (decrease) in Cash dividends within Appropriation of earnings from 2018 to 2019?[Error]
#  failure: [Error] good answer:  2849050
# f12806ca-aa4c-4fe6-84fc-10cefca76a9e
# What is the change in the operating revenue under continuing operations from 2018 to 2019? failure: 22772.0 good answer:  -22772
# f36e5912-f63c-4837-a9ed-ddbe73e5148b
# What is the percentage of the operating leases of more than 5 years in the total operating leases?[Error]invalid literal for int() with base 10: 'inthousands'
#  failure: [Error]invalid literal for int() with base 10: 'inthousands' good answer:  12.02
# 7ff6facd-1f7b-471c-9e38-5177c4eac9ba
# What is the percentage of capital leases in the total liabilities?[Error]invalid syntax (<string>, line 4)
#  failure: [Error]invalid syntax (<string>, line 4) good answer:  0.62
# d13b3204-0428-41af-8e4a-771dde352c50
# What is the percentage of the purchase obligations of more than 5 years in the total purchase obligations? failure: 2.64 good answer:  8.64
# e1ae4755-8038-4862-9f2f-b4197f9f2159
# What was the increase / (decrease) in the contractual obligation for operating leases from 2020 to 2021-2022? failure: 3.13 good answer:  2968
# Invalid  increased by thousand
# eb50d3aa-16da-4087-9ab2-10106ebd10e7
# What is the average annual Operating leases contractual obligations for 2020-2024?[Error]could not convert string to float: ''
#  failure: [Error]could not convert string to float: '' good answer:  2988
# 61451090-3f7b-4fb1-b405-64a786d937d8
# What was the increase / (decrease) in the asset retirement obligation from 2021-2022 to 2022-2023?[Error]
#  failure: [Error] good answer:  100
# 56a014a9-5b9c-41e5-9523-ebbd3a01dd6d
# What is the increase/ (decrease) in Statutory Audit, Certification, Audit of Individual and Consolidated Financial Statements from the period 2018 to 2019?[Outer Exception]cannot unpack non-iterable float object
# 593a3304-3fbe-47d2-a004-f4459ef3d014
# In 2019, what is the percentage constitution of prepaid expenses among the total prepaid expenses and other? failure: 100.0 good answer:  92.27
# 0f45cc67-fd57-4930-a0d0-f5d7174d7562
# What is the percentage change in the value of raw materials between 2018 and 2019? failure: 0 good answer:  16.23
# a30ab3a2-f930-4bf4-9b52-35c9c504d992
# What is the percentage change in the value of work-in-process inventory between 2018 and 2019? failure: 0.0 good answer:  -19.09
# 7df5635a-6f79-4fd2-8dc4-a5040e04cf4c
# What is the percentage change in the value of finished goods between 2018 and 2019?[Error]invalid decimal literal (<string>, line 3)
#  failure: [Error]invalid decimal literal (<string>, line 3) good answer:  -6.7
# da716abd-9641-4038-8f1d-4233fcf405ee
# What is the percentage change in the long-lived assets in United States from 2018 to 2019? Success: 18.94
# 3561fe2c-d1b1-4968-9d89-b6fa2d24bbe7
# What is the percentage change in the long-lived assets in Korea from 2018 to 2019? failure: 0.0 good answer:  15.99
# cd461457-bc43-45fe-9a82-147a7dd1c700
# What is the percentage change in the total long-lived assets from 2018 to 2019? failure: 0.0 good answer:  17.34
# 440e65d7-7c5c-4a28-871c-a828fa9860f3
# What was the average Services for 2018 and 2019? failure: (41097.67, 'thousand') good answer:  244800.5
# $$$$
# f1d5753b-05a9-4752-b03a-493e97804fb7
# What is the average total cost of revenue for 2018 and 2019? failure: 483769.5 good answer:  310566.5
# 2e3d4fe2-96f3-4ad9-b23f-1c590897b6e5
# What is the increase / (decrease) in the RSUs Granted from 2018 to 2019? failure: 556.0 good answer:  91
# 99f83ba7-2e57-44d8-ac0a-64ab3e9c7b47
# What is the average RSUs vested? failure: 424000.0 good answer:  424
# 8b2d5db2-7a47-4269-9df2-f44385bc0883
# What is the percentage increase / (decrease) in PSUs granted from 2018 to 2019? failure: 38.98 good answer:  38.98
# 9963bd65-093e-4801-8050-d2524ff06e7f
# For 2018, what is the percentage of constitution of employee severance and related costs among the total cost? failure: 42.42 good answer:  73.68
# f91f52fd-ed2d-448f-82ad-c95a10bc64d2
# What was the percentage change in total assets between 2015 and 2016? failure: -3.91 good answer:  5.42
# 568f039b-5753-4e91-b3aa-17cbcbe9b259
# What was the change in the Pre-contract costs from 2018 to 2020?[Outer Exception]cannot unpack non-iterable NoneType object
# 9634107c-5ee5-4ad0-bc6e-47d6651b4d07
# What is the average sales for years F19 and F18? failure: 1671.0 good answer:  1641.5
# e18e3335-7e7a-4138-9f1b-813604e44c3c
# What is the nominal difference in EBITDA between F19 and F18?[Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  11
# 9750180c-588d-4ba3-bc94-297d64b50e44
# What is the percentage constitution of Depreciation and Amortisation in EBITDA in F19?[Error]name 'depicion_amortisation' is not defined
#  failure: [Error]name 'depicion_amortisation' is not defined good answer:  29.84
# 7e058249-0f63-4002-912b-598bb9c62352
# What is the total value of computer equipment and software at the end of 2018 and 2019 altogether? Success: 28747.0
# afab19a4-a914-4a88-bc9d-699662b7fd3d
# What is the average value of computer equipment and software in both 2018 and 2019? failure: (7029.0, 7344.5) good answer:  14373.5
# $$$$
# Invalid  7344.5
# b11567d3-d651-40d8-9b9e-bc71eb37d7f9
# What was the percentage change in Transportation equipment in 2019 from 2018? Success: -3.62
# 93c3d11c-cf30-4464-a882-479f5f0b3f79
# What was the percentage change in total receivables, net between 2018 and 2019? failure: -1138.38 good answer:  6.52
# ffae65ab-7123-4c57-88a8-3bfec53e782a
# What was the change in Autodesk's goodwill from 2018 to 2019? failure: 59.1 good answer:  830.6
# f4abaf73-faa0-430f-8a7c-c499b84550bf
# What is the total ending goodwill for the years 2018 and 2019?[Error]name 'total_goodwell' is not defined
#  failure: [Error]name 'total_goodwell' is not defined good answer:  4071
# 9547b235-f8de-4c17-a9ac-e78277fcaf1a
# What is the average ending goodwill for the 2 year period from 2018 to 2019? Success: 2035.5
# 14381fab-36ac-482b-9f77-2c78f3f34ffb
# What was the change in Additions in 2019 from 2018? Success: 0.7
# 20092aeb-d39f-4b50-b927-0602b8a95c08
# What was the percentage change in Additions in 2019 from 2018?
# <string>:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <string>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# [Error]list indices must be integers or slices, not str
#  failure: [Error]list indices must be integers or slices, not str good answer:  29.17
# 775c21fd-9c4c-44d7-9879-81c2ca6d2420
# What was the percentage change in cash and cash equivalents from 2018 to 2019 year end?
# <string>:3: SyntaxWarning: 'generator' object is not subscriptable; perhaps you missed a comma?
# [Error]'generator' object is not subscriptable
#  failure: [Error]'generator' object is not subscriptable good answer:  25.39
# b70b2805-122b-436f-99cb-53be477a2b6e
# What was the percentage change in net inventories from 2018 to 2019 year end? Success: 34.61
# 732c81f8-a16d-4d34-9917-fa98c195feec
# What was the percentage change in accounts payables from 2018 to 2019 year end?[Outer Exception]cannot unpack non-iterable NoneType object
# 182dd9ea-dd5f-4ea0-bc30-bb42ef1f801c
# What percentage of the total unrealized gain is generated from U.S. government obligations in 2018?[Error]name 'total_unrealized_gain' is not defined
#  failure: [Error]name 'total_unrealized_gain' is not defined good answer:  2.84
# f6cb9974-2af7-43b3-9e1c-8cd5439dff67
# What percentage of the total amortized cost is made up of foreign government obligations in 2018?[Error]float division by zero
#  failure: [Error]float division by zero good answer:  43.15
# f6ccfc15-3970-467d-b83e-e2ce0ff365e3
# What were the total expenses in 2019? failure: 42959.0 good answer:  82884
# 405f18a8-803b-4f68-be49-7490b74b3697
# What was the change in Earnings before interest and taxes EBIT in 2018/2019 from 2017/2018? failure: 0.0 good answer:  115
# c5757bb4-a312-48ed-a244-29932669363c
# What was the percentage change in Earnings before interest and taxes EBIT in 2018/2019 from 2017/2018? failure: 16.00 percent good answer:  16.13
# 1504af2b-2364-4a59-8883-634a4ef67a34
# What was the average orders for 2019 and 2018? failure: (12749.0, 'million') good answer:  12312
# $$$$
# 7a77310d-bdbd-4ddd-886d-15b70985e957
# What is the increase / (decrease) in revenue from 2018 to 2019? failure: -10.8 good answer:  1105
# ef466edc-6087-429c-89ac-359e6cb0977f
# What is the increase / (decrease) in the Adjusted EBITDA margin from 2018 to 2019? failure: -0.11 good answer:  -0.6000000000000001
# Invalid  -
# c36e2211-e46a-43d1-a0a8-ae87af347ae8
# What was the change in the Net cash provided by (used in) investing activities from 2017 to 2018? failure: 43.0 good answer:  -43
# 163f08ab-cfae-426a-9c03-4f84feba3bb6
# What was the average Net cash used in financing activities between fiscal years 2017-2019? failure: -615.0 good answer:  615
# e81574d8-f9e8-48b3-85ab-a7ed36f8cbb0
# What was the change in Acquisition and integration costs in 2019 from 2018? Success: 9.0
# 426e47ae-aff7-43e2-81be-0bb951b0def1
# What was the percentage change in Acquisition and integration costs in 2019 from 2018? failure: Percentage Change good answer:  112.5
# 07148f97-1ced-46e4-a141-5cdffe6e6528
# What was the change in the (Loss)/profit before taxation from 2018 to 2019? failure: 0.0 good answer:  -63.6
# 88795fae-3c5b-48d4-ae2d-57fe04b15c31
# What is the average Non-deductible items for 2018 and 2019? Success: -0.5
# ed9e3e80-6941-4888-9e40-bbd1cb092485
# What was the average Adjustment for share-based payments for 2018 and 2019?[Error]division by zero
#  failure: [Error]division by zero good answer:  -0.5
# 5f282807-f3fe-4efd-a4ef-b88a3d580bf9
# What was the change in revenue from external customers from UK in 2019 from 2018? failure: 0.0 good answer:  9.7
# 44f28f4e-ce84-4300-b8d1-1644dda31933
# What was the percentage change in revenue from external customers from UK in 2019 from 2018? Success: 13.2
# cfbbdf60-d0d7-458c-853c-d1ffa1e8356f
# What was the increase / (decrease) in the Furniture and equipment from 2018 to 2019? failure: -933.0 good answer:  933
# a032279a-fde8-4152-9350-e5a9340f27c4
# What was the average Furniture and equipment for 2018 and 2019?[Error]could not convert string to float: ''
#  failure: [Error]could not convert string to float: '' good answer:  11137.5
# f5eb2ada-9a3c-4bbd-b96d-a83844cef935
# What was the average leasehold improvements for 2018 and 2019? Success: 6900.0
# 5c59c850-a720-4b1f-b703-9e1d9ff8e242
# What was the change in Accrued pension liabilities in 2019 from 2018? Success: 0.10000000000000009
# 4f1d7142-98fe-4e6a-b8ea-3c2c451f5037
# What was the percentage change in Accrued pension liabilities in 2019 from 2018? Success: 3.03
# e3041bef-c305-431f-b165-54cb8bca77fb
# What was the change in Inventory between 2018 and 2019?[Outer Exception]cannot unpack non-iterable NoneType object
# c0d6605c-50c2-42b1-94f6-c4c601559918
# What was the change in the State income taxes, net of federal tax benefit from 2017 to 2018? failure: -9.0 good answer:  -21
# b194279c-16e5-4a17-9733-c8babb6e8281
# What is the average Excess tax benefits from stock-based compensation in 2018 and 2017? Success: -10.5
# 81cab6e1-acb6-4c1e-a5f7-ae283cbd1b53
# What is the net difference in sale of systems between 2017 and 2019? failure: -531.92 good answer:  -531925
# ff1e12e8-e148-470f-95a8-3f23e02fa62d
# What is the net difference in sale of modules between 2017 and 2019? failure: -151721885.0 good answer:  653718
# a4be9eab-ad03-4d67-9136-62d7cbe40e1e
# What is the net percentage difference in net sales between 2017 and 2019? failure: 100.0 good answer:  4.14
# Invalid  1000
# 162f80b9-b689-4405-b6b2-5e98d3882ce7
# What is the change in Trade receivables from 2018 to 2019? Success: 716.0
# 0b7463b3-ed9e-47a0-b838-b26e0ab886eb
# What is the change in Allowance for expected credit losses from 2018 to 2019? failure: -112.0 good answer:  112
# Invalid  None
# acbacb07-2a66-418b-b6da-53424c35abd5
# What is the change in Other receivables from 2018 to 2019? failure: -342.0 good answer:  141
# 49e5b466-62c9-4cab-8d70-8e9317e7a007
# In the first quarter of 2018, what is the difference between the low and high price? failure: 40.23 good answer:  2.41
# 5beff07b-d9e0-4592-b11a-47bc4bbb5e07
# What is the average quarterly low price in 2018? Success: 3.83
# 7707ff1b-ca2c-4d72-aad1-81315a5f54ff
# What is the change in the value of Total inventories between October 31, 2019 and 2018? Success: 49872.0
# 12005950-7f78-497e-a1b4-cfc8c7389aa1
# What is the average value of Packaging materials for October 31, 2019 and 2018?[Error]division by zero
#  failure: [Error]division by zero good answer:  7017.5
# 297b00ae-9c26-4401-82b5-a6de76674ee9
# What is the average value of Prepared chicken for October 31, 2019 and 2018? failure: 16.81 good answer:  16811.5
# ebae8430-83a7-49c7-af14-99ddf4b1e376
# What is the total amount of audit fees in both 2018 and 2019? failure: 1.13 good answer:  113000
# 1fe30b3b-c8d4-47e2-a4b2-d2a583da9ce7
# What is the percentage change in tax fees from 2018 to 2019?[Error]name 'run' is not defined
#  failure: [Error]name 'run' is not defined good answer:  -60.71
# 2d0072b8-5110-4323-ac2e-0d294045da92
# What is the percentage of audit fees in total fees in 2019? failure: 100.0 good answer:  83.33
# c34555c9-39a6-4505-bc7e-fcabfa3ae6cd
# What is the net total underlying rights and other for both finite-lived and indefinite-lived intangible assets as of June 30, 2019? failure: 9.25 good answer:  16.4
# 2e569f93-d58b-44a7-a947-ea6784b0623d
# What is the increase/ (decrease) in Revenues from, 2019 to 2018? Success: 90494.0
# fd59c14d-0312-4725-92d8-5c30cd5c5c7a
# What is the increase/ (decrease) in Voyage expenses from, 2019 to 2018? failure: 24.26 good answer:  -6850
# 4cf34f4c-68c1-40f0-bb79-80ee15b256ed
# What is the average tax related accruals for 2018 and 2019? failure: 38.4 good answer:  34.6
# ea159bf1-8401-4540-b5a7-8fbdb5476944
# What is the average accrued payroll and employee benefits for 2018 and 2019? Success: 111.4
# 79f51c3d-59d3-4abc-b0cd-d9e28668fbf4
# What is the average derivative liabilities for 2018 and 2019? failure: 120.5 good answer:  107.15
# Invalid  93.8
# 2b5044df-ad20-4146-a571-e778cfc88c8d
# What is the percentage change of the investments accounted for at cost, adjusted for observable price changes between 2018 and 2019? failure: 0.0 good answer:  40
# 170c75fb-da08-4e9d-8c5a-7cbb94e4176e
# What percentage of total non-marketable investments were accounted for using the equity method in 2019?

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)

# %%
import re
res2 = []
for ans, pred, pred_scale, q,code, table,value_list,err in res:
    good = utils.eval_predicted_value(pred, ans['answer'])
    regex = re.compile("\\(\\d+,?\\d+", re.VERBOSE)    
    match = regex.search(str(table))
    
    match = match != None
    if pred == None:
        pred = 0
    res2.append( {'qid': q['uid'], 'question' : q['question'], 'derivation': q['derivation'], 'pred' : pred, 'pred_scale': pred_scale,  'answer': ans['answer'],  'scale':  ans['scale'],  'abs': 'abs(' in code, 'inv' : ans['answer'] == -1*pred,  'good': good, 'parenth': match})
res2 = pd.DataFrame(res2)
print(len(res2.query('good == True'))/len(res2))
# Out:
# 0.026915113871635612

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [-1.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [4044.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [2349.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [16458.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [995.7],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12122000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [6.47],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [56.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [17.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [5309.6],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [244800.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-568.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [259.8],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-6841.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [63888.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.69999999999993],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [1303.1],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [8.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [-153391.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9307.75],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [201554.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
# ...
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [3695.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [4.52],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [-63.99],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1581.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [48784.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [1.32],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [36694.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [1.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [36.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
metrics._details[0]['pred'][0] == -94
# Out:
# True

# %%
scale_err =  [item for item in metrics._details if item['em'] != 1.0 and item['pred_scale'] != item['scale']]
only_scale_err =  [item for item in metrics._details if item['em'] != 1.0 and isinstance(item['pred'], list)  and  item['pred'][0] == item['answer']]
err =  [item for item in metrics._details if item['em'] != 1.0]
len (metrics._details), len(err), len(scale_err), len(only_scale_err)
# Out:
# (166, 56, 31, 20)

# %%
res = {}
for item in metrics._details:
  

    pred = item['pred']
    pred_scale = item['pred_scale']

    key = pred_scale +'|' + item['scale']
    if key not in res:
        res [key] = 1
    res[key]=res[key] +1


    if  item['em'] == 1.0:
        None
        #print("\033[92m Success: " + str(pred)+'\033[0m')
    else:           
 
        
        if isinstance(item['pred'], list) and  pred[0] == item['answer']:
           
            print("\033[93m", '|', " failure: ", '| ',str(pred[0]),  '| ', str(pred_scale), '| ', 'good answer: ', '| ', item['answer'], '| ', item['scale'], '\033[0m' )
        else:    
            None
            #print("\033[91m failure: " + str(pred),  str(pred_scale), 'good answer: ',item['answer'],item['scale'], '\033[0m' )
# Out:
#  |  failure:  |  62740.0 |   |  good answer:  |  62740 |  thousand
#  |  failure:  |  -19411.0 |   |  good answer:  |  -19411 |  thousand
#  |  failure:  |  12085176.0 |  thousand |  good answer:  |  12085176 |
#  |  failure:  |  28747.0 |  thousand |  good answer:  |  28747 |
#  |  failure:  |  113000.0 |  thousand |  good answer:  |  113000 |
#  |  failure:  |  111.4 |  million |  good answer:  |  111.4 |
#  |  failure:  |  107.15 |  million |  good answer:  |  107.15 |
#  |  failure:  |  -27603.0 |  thousand |  good answer:  |  -27603 |
#  |  failure:  |  3.0 |  million |  good answer:  |  3 |
#  |  failure:  |  -10029.67 |   |  good answer:  |  -10029.67 |  thousand
#  |  failure:  |  39.33 |  million |  good answer:  |  39.33 |
#  |  failure:  |  0.08 |  thousand |  good answer:  |  0.08 |  percent
#  |  failure:  |  16767.0 |   |  good answer:  |  16767 |  thousand
#  |  failure:  |  0.1 |   |  good answer:  |  0.1 |  million
#  |  failure:  |  54633874 |  thousand |  good answer:  |  54633874 |
#  |  failure:  |  0.18 |  thousand |  good answer:  |  0.18 |
#  |  failure:  |  0.97 |  thousand |  good answer:  |  0.97 |
#  |  failure:  |  3695.0 |  million |  good answer:  |  3695 |  thousand
#  |  failure:  |  39.3 |  million |  good answer:  |  39.3 |  percent
#  |  failure:  |  2.65 |  thousand |  good answer:  |  2.65 |
#  |  failure:  |  -0.2 |  million |  good answer:  |  -0.2 |  percent
#  |  failure:  |  1336.7 |  thousand |  good answer:  |  1336.7 |

# %%
res
# Out:
# {'million|million': 121,
#  'percent|percent': 177,
#  '|': 65,
#  'thousand|thousand': 82,
#  '|thousand': 11,
#  '|percent': 14,
#  'percent|': 3,
#  '|million': 5,
#  'thousand|': 11,
#  'million|percent': 5,
#  'million|': 9,
#  'thousand|percent': 2,
#  'billion|billion': 4,
#  'million|thousand': 2}

# %%
res
# Out:
# {'|thousand': 5,
#  'thousand|': 10,
#  'million|': 4,
#  'thousand|percent': 2,
#  '|million': 7,
#  'million|thousand': 2,
#  'million|percent': 3}

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [121.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [3680.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [3728.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [88.45],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12136.91],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [0.95],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [-56.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [-17.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': [2.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [4859.25],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [36.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-615.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [112.5],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-16105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [42592.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': [0.18],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [700.45],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [113.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [-9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9548.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [100777.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61,
#   'scale': 'percent',
#   'pred': [61.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 622908,
#   'scale': 'thousand',
#   'pred': [623111.0],
# ...
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 202845,
#   'scale': '',
#   'pred': [202845.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [11085.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [42.23],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [36.01],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1022.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [28101.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [-1.32],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [61584.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [0.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [100.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]
